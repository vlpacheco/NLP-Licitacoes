# %% [markdown]
# #  _*Exploratory-Data-Analysis-Year-2019*_

# %% [markdown]
# ---
# ## _*1) Analise das Licitacoes - Ano 2019 - licitacoes.csv*_
#
# ---

# %% [markdown]
# ---
# ###  _*Carregamento e identificacao dos dados*_
#  _*Secao destinada ao carregamento e analise inicial dos dados*_
#
#  _*Com isso, uma análise inicial de formato e tipo de variáveis é conduzido.*_
#
# ---

# %%
#Importanto as bibliotecas // Todos imports devem ser realizados aqui
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Carregabdo o dataset "licitacao.csv" 
df_licitacao = pd.read_csv('licitacao.csv')

#Visualizando as primeiras colunas
df_licitacao.head()
# Out:
# /Users/viniciuspacheci/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: DtypeWarning: Columns (53,54) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    CD_ORGAO                                      NM_ORGAO  NR_LICITACAO  \
# 0     53100                              PM DE NOVA PALMA           3.0
# 1     53100                              PM DE NOVA PALMA           1.0
# 2     51802  CIA. ÁGUAS TERMAIS MARCELINO RAMOS - TERMASA           3.0
# 3     84100                        PM DE ESPERANÇA DO SUL          34.0
# 4     86800                        PM DE BOA VISTA DO SUL           3.0
#
#    ANO_LICITACAO CD_TIPO_MODALIDADE  NR_COMISSAO  ANO_COMISSAO TP_COMISSAO  \
# 0           2019                TMP       6679.0        2018.0           P
# 1           2019                TMP       6679.0        2018.0           P
# 2           2019                EST          1.0        2018.0           P
# 3           2019                CNV        326.0        2017.0           P
# 4           2019                PRP          4.0        2019.0           G
#
#   NR_PROCESSO  ANO_PROCESSO  ... TP_DOCUMENTO_FORNECEDOR  \
# 0         101        2019.0  ...                     NaN
# 1         035        2019.0  ...                     NaN
# 2           3        2019.0  ...                     NaN
# 3         415        2019.0  ...                     NaN
# 4         004        2019.0  ...                     NaN
#
#   NR_DOCUMENTO_FORNECEDOR TP_DOCUMENTO_VENCEDOR NR_DOCUMENTO_VENCEDOR  \
# 0                     NaN                     J        09616071000198
# 1                     NaN                     J        09616071000198
# 2                     NaN                     J        23178651000171
# 3                     NaN                     J        90167065000119
# 4                     NaN                     J        02934207000169
#
#   VL_HOMOLOGADO BL_GERA_DESPESA DS_OBSERVACAO PC_TX_ESTIMADA PC_TX_HOMOLOGADA  \
# 0     272269.69               S           NaN            NaN              NaN
# 1      75363.72               S           NaN            NaN              NaN
# 2     126240.00               N           NaN            NaN              NaN
# 3       9600.00               S           NaN            NaN              NaN
# 4     430770.00               S           NaN            NaN              NaN
#
#   BL_COMPARTILHADA
# 0                N
# 1                N
# 2                N
# 3                N
# 4                N
#
# [5 rows x 61 columns]

# %%
#Formato do dataset
print('Dataset shape is: {}' .format(df_licitacao.shape))
# Out:
# Dataset shape is: (70546, 61)

# %%
#Visualizando as informacoes e tipos de variaveis existentes
df_licitacao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70546 entries, 0 to 70545
# Data columns (total 61 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CD_ORGAO                     70546 non-null  int64
#  1   NM_ORGAO                     70546 non-null  object
#  2   NR_LICITACAO                 70546 non-null  float64
#  3   ANO_LICITACAO                70546 non-null  int64
#  4   CD_TIPO_MODALIDADE           70546 non-null  object
#  5   NR_COMISSAO                  42584 non-null  float64
#  6   ANO_COMISSAO                 42584 non-null  float64
#  7   TP_COMISSAO                  42584 non-null  object
#  8   NR_PROCESSO                  70462 non-null  object
#  9   ANO_PROCESSO                 70463 non-null  float64
#  10  TP_OBJETO                    70546 non-null  object
#  11  CD_TIPO_FASE_ATUAL           70546 non-null  object
#  12  TP_LICITACAO                 70546 non-null  object
#  13  TP_NIVEL_JULGAMENTO          70546 non-null  object
#  14  DT_AUTORIZACAO_ADESAO        736 non-null    object
#  15  TP_CARACTERISTICA_OBJETO     70546 non-null  object
#  16  TP_NATUREZA                  70546 non-null  object
#  17  TP_REGIME_EXECUCAO           14905 non-null  object
#  18  BL_PERMITE_SUBCONTRATACAO    46365 non-null  object
#  19  TP_BENEFICIO_MICRO_EPP       70546 non-null  object
#  20  TP_FORNECIMENTO              33912 non-null  object
#  21  TP_ATUACAO_REGISTRO          6939 non-null   object
#  22  NR_LICITACAO_ORIGINAL        783 non-null    object
#  23  ANO_LICITACAO_ORIGINAL       12411 non-null  float64
#  24  NR_ATA_REGISTRO_PRECO        782 non-null    object
#  25  DT_ATA_REGISTRO_PRECO        767 non-null    object
#  26  PC_TAXA_RISCO                16358 non-null  float64
#  27  TP_EXECUCAO                  21295 non-null  object
#  28  TP_DISPUTA                   250 non-null    object
#  29  TP_PREQUALIFICACAO           250 non-null    object
#  30  BL_INVERSAO_FASES            70546 non-null  object
#  31  TP_RESULTADO_GLOBAL          10392 non-null  object
#  32  CNPJ_ORGAO_GERENCIADOR       5477 non-null   float64
#  33  NM_ORGAO_GERENCIADOR         5477 non-null   object
#  34  DS_OBJETO                    70546 non-null  object
#  35  CD_TIPO_FUNDAMENTACAO        32754 non-null  object
#  36  NR_ARTIGO                    7843 non-null   float64
#  37  DS_INCISO                    1520 non-null   object
#  38  DS_LEI                       1609 non-null   object
#  39  DT_INICIO_INSCR_CRED         816 non-null    object
#  40  DT_FIM_INSCR_CRED            825 non-null    object
#  41  DT_INICIO_VIGEN_CRED         747 non-null    object
#  42  DT_FIM_VIGEN_CRED            747 non-null    object
#  43  VL_LICITACAO                 67086 non-null  float64
#  44  BL_ORCAMENTO_SIGILOSO        28701 non-null  object
#  45  BL_RECEBE_INSCRICAO_PER_VIG  7042 non-null   object
#  46  BL_PERMITE_CONSORCIO         70546 non-null  object
#  47  DT_ABERTURA                  70537 non-null  object
#  48  DT_HOMOLOGACAO               38579 non-null  object
#  49  DT_ADJUDICACAO               36089 non-null  object
#  50  BL_LICIT_PROPRIA_ORGAO       70546 non-null  object
#  51  TP_DOCUMENTO_FORNECEDOR      19341 non-null  object
#  52  NR_DOCUMENTO_FORNECEDOR      19341 non-null  float64
#  53  TP_DOCUMENTO_VENCEDOR        4536 non-null   object
#  54  NR_DOCUMENTO_VENCEDOR        4536 non-null   object
#  55  VL_HOMOLOGADO                25779 non-null  float64
#  56  BL_GERA_DESPESA              70546 non-null  object
#  57  DS_OBSERVACAO                1972 non-null   object
#  58  PC_TX_ESTIMADA               30 non-null     float64
#  59  PC_TX_HOMOLOGADA             22 non-null     float64
#  60  BL_COMPARTILHADA             70546 non-null  object
# dtypes: float64(13), int64(2), object(46)
# memory usage: 32.8+ MB

# %%
#Verificando o numero de colunas nulas
df_licitacao.isnull().sum()

#Muitas colunas com valores nulos, importante selecionar os termos de interesse da analise
# Out:
# CD_ORGAO                  0
# NM_ORGAO                  0
# NR_LICITACAO              0
# ANO_LICITACAO             0
# CD_TIPO_MODALIDADE        0
#                       ...
# BL_GERA_DESPESA           0
# DS_OBSERVACAO         68574
# PC_TX_ESTIMADA        70516
# PC_TX_HOMOLOGADA      70524
# BL_COMPARTILHADA          0
# Length: 61, dtype: int64

# %% [markdown]
# ---
# ### _*Avaliando os dados numéricos*_
# _*Avaliar tipos de variáveis e estrutura dos dados*_
#
# ---

# %%
#Verificando as colunas numericas
numeric_data = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

#Utilizacao do "select dtype" para encontrar valores numericos
numeric_df = df_licitacao.select_dtypes(include = numeric_data)

#Plotando colunas numericas
numeric_df
# Out:
#        CD_ORGAO  NR_LICITACAO  ANO_LICITACAO  NR_COMISSAO  ANO_COMISSAO  \
# 0         53100           3.0           2019       6679.0        2018.0
# 1         53100           1.0           2019       6679.0        2018.0
# 2         51802           3.0           2019          1.0        2018.0
# 3         84100          34.0           2019        326.0        2017.0
# 4         86800           3.0           2019          4.0        2019.0
# ...         ...           ...            ...          ...           ...
# 70541     58706          24.0           2019          NaN           NaN
# 70542     56900          39.0           2019          NaN           NaN
# 70543     58701           2.0           2019          NaN           NaN
# 70544     88029          28.0           2019         44.0        2019.0
# 70545     56900          19.0           2019          7.0        2019.0
#
#        ANO_PROCESSO  ANO_LICITACAO_ORIGINAL  PC_TAXA_RISCO  \
# 0            2019.0                     0.0            0.0
# 1            2019.0                     NaN            NaN
# 2            2019.0                     NaN            NaN
# 3            2019.0                     NaN            NaN
# 4            2019.0                     NaN            NaN
# ...             ...                     ...            ...
# 70541        2019.0                     NaN            NaN
# 70542        2019.0                     NaN            NaN
# 70543        2019.0                     NaN            NaN
# 70544        2019.0                     NaN            NaN
# 70545        2019.0                     NaN            NaN
#
#        CNPJ_ORGAO_GERENCIADOR  NR_ARTIGO  VL_LICITACAO  \
# 0                         NaN        0.0     276405.12
# 1                         NaN        NaN      75396.00
# 2                         NaN        NaN     105612.48
# 3                         NaN        NaN      10600.00
# 4                         NaN        NaN     430770.00
# ...                       ...        ...           ...
# 70541                     NaN        NaN       6100.00
# 70542                     NaN        NaN      76810.50
# 70543                     NaN        NaN      11585.40
# 70544                     NaN        NaN      15466.15
# 70545                     NaN        NaN       7088.52
#
#        NR_DOCUMENTO_FORNECEDOR  VL_HOMOLOGADO  PC_TX_ESTIMADA  \
# 0                          NaN      272269.69             NaN
# 1                          NaN       75363.72             NaN
# 2                          NaN      126240.00             NaN
# 3                          NaN        9600.00             NaN
# 4                          NaN      430770.00             NaN
# ...                        ...            ...             ...
# 70541             3.603050e+11            NaN             NaN
# 70542             2.191788e+12            NaN             NaN
# 70543             1.253920e+11            NaN             NaN
# 70544                      NaN            NaN             NaN
# 70545                      NaN            NaN             NaN
#
#        PC_TX_HOMOLOGADA
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 70541               NaN
# 70542               NaN
# 70543               NaN
# 70544               NaN
# 70545               NaN
#
# [70546 rows x 15 columns]

# %%
#Formato das colunas numericas
numeric_df.shape

#Valores numericos observado em 16 colunas e todas linhas do dataset
#Porem, há valores com "IDs", "Anos", "Numero de documento" e afins,
#que nao representam variaveis numericas e sim categoricas expressas
#em numeros
# Out:
# (70546, 15)

# %%
#Comprovando a nao linearidade dos valores numericos atraves da
#funcao de correlacao "corr()", por serem de fato categoricos
corr = numeric_df.corr()
corr.style.background_gradient(cmap='coolwarm') #Tentativa de plot, apenas para comprovacao
# Out:
# /Users/viniciuspacheci/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/style.py:2813: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# /Users/viniciuspacheci/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/style.py:2814: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_bf592_row0_col0, #T_bf592_row1_col1, #T_bf592_row3_col3, #T_bf592_row4_col4, #T_bf592_row5_col5, #T_bf592_row6_col6, #T_bf592_row7_col7, #T_bf592_row8_col8, #T_bf592_row9_col9, #T_bf592_row10_col10, #T_bf592_row11_col11, #T_bf592_row12_col12, #T_bf592_row13_col13, #T_bf592_row14_col14 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_bf592_row0_col1, #T_bf592_row3_col5, #T_bf592_row5_col11 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_bf592_row0_col2, #T_bf592_row1_col2, #T_bf592_row2_col0, #T_bf592_row2_col1, #T_bf592_row2_col2, #T_bf592_row2_col3, #T_bf592_row2_col4, #T_bf592_row2_col5, #T_bf592_row2_col6, #T_bf592_row2_col7, #T_bf592_row2_col8, #T_bf592_row2_col9, #T_bf592_row2_col10, #T_bf592_row2_col11, #T_bf592_row2_col12, #T_bf592_row2_col13, #T_bf592_row2_col14, #T_bf592_row3_col2, #T_bf592_row4_col2, #T_bf592_row5_col2, #T_bf592_row6_col2, #T_bf592_row6_col7, #T_bf592_row6_col13, #T_bf592_row6_col14, #T_bf592_row7_col2, #T_bf592_row7_col6, #T_bf592_row7_col8, #T_bf592_row7_col9, #T_bf592_row7_col11, #T_bf592_row7_col12, #T_bf592_row7_col13, #T_bf592_row7_col14, #T_bf592_row8_col2, #T_bf592_row8_col7, #T_bf592_row8_col13, #T_bf592_row8_col14, #T_bf592_row9_col2, #T_bf592_row9_col7, #T_bf592_row9_col13, #T_bf592_row9_col14, #T_bf592_row10_col2, #T_bf592_row11_col2, #T_bf592_row11_col7, #T_bf592_row11_col12, #T_bf592_row11_col13, #T_bf592_row11_col14, #T_bf592_row12_col2, #T_bf592_row12_col7, #T_bf592_row12_col11, #T_bf592_row13_col2, #T_bf592_row13_col6, #T_bf592_row13_col7, #T_bf592_row13_col8, #T_bf592_row13_col9, #T_bf592_row13_col11, #T_bf592_row14_col2, #T_bf592_row14_col6, #T_bf592_row14_col7, #T_bf592_row14_col8, #T_bf592_row14_col9, #T_bf592_row14_col11 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_bf592_row0_col3, #T_bf592_row1_col6, #T_bf592_row14_col5 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_bf592_row0_col4, #T_bf592_row5_col9 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_bf592_row0_col5, #T_bf592_row10_col9 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_bf592_row0_col6, #T_bf592_row8_col5 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_bf592_row0_col7, #T_bf592_row0_col8, #T_bf592_row0_col9, #T_bf592_row0_col14, #T_bf592_row1_col7, #T_bf592_row1_col13, #T_bf592_row3_col7, #T_bf592_row4_col7, #T_bf592_row5_col7, #T_bf592_row6_col5, #T_bf592_row6_col11, #T_bf592_row8_col3, #T_bf592_row9_col4, #T_bf592_row10_col7, #T_bf592_row11_col4, #T_bf592_row11_col6, #T_bf592_row13_col1, #T_bf592_row14_col0, #T_bf592_row14_col10, #T_bf592_row14_col12 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_bf592_row0_col10, #T_bf592_row1_col10, #T_bf592_row1_col12, #T_bf592_row3_col10, #T_bf592_row4_col10, #T_bf592_row5_col10, #T_bf592_row5_col12, #T_bf592_row6_col8, #T_bf592_row6_col10, #T_bf592_row7_col10, #T_bf592_row10_col12, #T_bf592_row12_col10 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_bf592_row0_col11, #T_bf592_row3_col9 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_bf592_row0_col12, #T_bf592_row11_col9 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_bf592_row0_col13 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_bf592_row1_col0 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_bf592_row1_col3, #T_bf592_row7_col3, #T_bf592_row10_col3, #T_bf592_row12_col14 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_bf592_row1_col4, #T_bf592_row3_col4, #T_bf592_row10_col4 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_bf592_row1_col5, #T_bf592_row4_col5, #T_bf592_row13_col3 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_bf592_row1_col8 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_bf592_row1_col9 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_bf592_row1_col11, #T_bf592_row4_col6, #T_bf592_row10_col11 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_bf592_row1_col14 {
#   background-color: #f7ba9f;
#   color: #000000;
# }
# #T_bf592_row3_col0, #T_bf592_row12_col0 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_bf592_row3_col1, #T_bf592_row4_col1, #T_bf592_row4_col3, #T_bf592_row7_col1, #T_bf592_row10_col1, #T_bf592_row12_col1 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_bf592_row3_col6 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_bf592_row3_col8, #T_bf592_row6_col1 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_bf592_row3_col11 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_bf592_row3_col12, #T_bf592_row11_col3 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_bf592_row3_col13, #T_bf592_row12_col6 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_bf592_row3_col14 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_bf592_row4_col0 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_bf592_row4_col8, #T_bf592_row6_col3, #T_bf592_row13_col10 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_bf592_row4_col9, #T_bf592_row6_col4 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_bf592_row4_col11, #T_bf592_row8_col0, #T_bf592_row8_col4, #T_bf592_row9_col6 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_bf592_row4_col12, #T_bf592_row6_col12, #T_bf592_row9_col10, #T_bf592_row9_col12, #T_bf592_row10_col13 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_bf592_row4_col13 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_bf592_row4_col14 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_bf592_row5_col0, #T_bf592_row12_col8 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_bf592_row5_col1, #T_bf592_row9_col1, #T_bf592_row9_col3 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_bf592_row5_col3 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_bf592_row5_col4 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_bf592_row5_col6 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_bf592_row5_col8 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_bf592_row5_col13 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_bf592_row5_col14 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_bf592_row6_col0 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_bf592_row6_col9 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_bf592_row7_col0, #T_bf592_row10_col0 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_bf592_row7_col4, #T_bf592_row8_col6, #T_bf592_row12_col4 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_bf592_row7_col5, #T_bf592_row10_col5, #T_bf592_row12_col5 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_bf592_row8_col1 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_bf592_row8_col9 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_bf592_row8_col10 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_bf592_row8_col11 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_bf592_row8_col12, #T_bf592_row9_col11 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_bf592_row9_col0, #T_bf592_row14_col3 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_bf592_row9_col5 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_bf592_row9_col8 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_bf592_row10_col6, #T_bf592_row11_col5, #T_bf592_row12_col13 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_bf592_row10_col8 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_bf592_row10_col14 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_bf592_row11_col0 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_bf592_row11_col1, #T_bf592_row12_col3, #T_bf592_row13_col4 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_bf592_row11_col8 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_bf592_row11_col10, #T_bf592_row14_col4 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_bf592_row12_col9 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_bf592_row13_col0 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_bf592_row13_col5 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_bf592_row13_col12 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_bf592_row13_col14 {
#   background-color

# %% [markdown]
# ---
# ###  _*Trabalhando com dados numericos - TP_OBJETO e VL_HOMOLOGADO*_
#
# O intuito da presente analise seria agrupar por valores os orgaoes e com isso identificar os IDs referentes aos maiores valores licitados. Tendo como premissa o VAL_HOMOLOGADO
#
# ---

# %%
#Selecao de variaveis para analise do VL_LICITACAO
#Identificacao das variaveis importantes para elencar licitacoes
#de acordo com o orgao

#Variaveis categoricas, representadas numericamente para analise
#CD_ORGAO --> Codigo do Orgao

#Justificativa: Analise numerica de relacao de valores por orgao.
#Analise do elemento com maior incidencia deve ser feito sob
#outra perspectiva

#Selecao também do requisito recomendado TP_OBJETO = COM
df_analise = df_licitacao[['CD_ORGAO', 'VL_HOMOLOGADO', 'TP_OBJETO']]
df_analise
# Out:
#        CD_ORGAO  VL_HOMOLOGADO TP_OBJETO
# 0         53100      272269.69       CSE
# 1         53100       75363.72       OSE
# 2         51802      126240.00       PER
# 3         84100        9600.00       OUS
# 4         86800      430770.00       OUS
# ...         ...            ...       ...
# 70541     58706            NaN       OUS
# 70542     56900            NaN       COM
# 70543     58701            NaN       CSE
# 70544     88029            NaN       OUS
# 70545     56900            NaN       COM
#
# [70546 rows x 3 columns]

# %%
#Criacao condicional do dataset, apenas dados de compra
df_analise = df_analise.loc[df_analise['TP_OBJETO'] == 'COM']

# %%
#Formato do novo dataset
print('Dataset shape is: {}' .format(df_analise.shape))
# Out:
# Dataset shape is: (22330, 3)

# %%
#Eliminacao de valor NaN na coluna VL_LICITACAO
df_analise = df_analise[df_analise['VL_HOMOLOGADO'].notna()]

# %%
#Formato do novo dataset sem NaN 
print('Dataset shape is: {}' .format(df_analise.shape))
# Out:
# Dataset shape is: (9034, 3)

# %%
#Removendo valores iguais a zero
#Justificativa: Elementos com zero nao influenciam
#no resultado da analise
df_analise = df_analise[(df_analise != 0).all(1)]

# %%
#Formato do novo dataset sem zeros
print('Dataset shape is: {}' .format(df_analise.shape))
# Out:
# Dataset shape is: (5716, 3)

# %%
#Avaliando a distribuicao pelo histograma da variavel
#Observa-se forte distorcao nos dados e nao linearidade
#Ou seja, há valores exorbitantes e valores irrisórios
sns.distplot(df_analise['VL_HOMOLOGADO'])
# Out:
# /Users/viniciuspacheci/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='VL_HOMOLOGADO', ylabel='Density'>

# %%
#Avaliando através de estatistica descritiva a VL_LICITACAO
#Justifica-se o encontrado na distribuicao do histograma
df_analise['VL_HOMOLOGADO'].describe()
# Out:
# count    5.716000e+03
# mean     5.633280e+05
# std      2.103644e+07
# min      4.000000e-02
# 25%      1.677411e+04
# 50%      5.027478e+04
# 75%      1.629772e+05
# max      1.583767e+09
# Name: VL_HOMOLOGADO, dtype: float64

# %% [markdown]
# ---
# ### _*Agrupando as colunas de interesse*_
#
# #### _*Agrupando e calcular metricas basicas: min, ma e media (mean)*_
#
# ---

# %%
#Agrupando em forma de Multiindex as colunas
df_analise_grouped = df_analise.groupby('CD_ORGAO').agg({'VL_HOMOLOGADO': ['mean',
                                                                         'min', 'max']})

# %%
#Renomeando as colunas, para nao trabalhar com multiindex

#Renomeando as colunas
df_analise_grouped.columns = ['VL_HOMOLOGADO-mean', 'VL_HOMOLOGADO-min', 'VL_HOMOLOGADO-max']

#Resetando o index
df_analise_grouped = df_analise_grouped.reset_index()

# %%
#Replotando o DataFrame com as colunas renomeadas
df_analise_grouped
# Out:
#      CD_ORGAO  VL_HOMOLOGADO-mean  VL_HOMOLOGADO-min  VL_HOMOLOGADO-max
# 0         900        7.387836e+06              30.00        94472000.00
# 1        1593        1.990000e+04           19900.00           19900.00
# 2        3400        3.102771e+04            7425.00           54630.42
# 3        4000        5.305842e+04           34800.00           70433.67
# 4        6900        1.661700e+03             860.00            3240.00
# ..        ...                 ...                ...                ...
# 345     88300        1.093028e+05           13599.99          385611.30
# 346     88313        1.688000e+04           14200.00           19560.00
# 347     88326        2.044568e+04               7.72          104500.00
# 348     88328        2.056393e+05          205639.28          205639.28
# 349     88394        7.590000e+04           75900.00           75900.00
#
# [350 rows x 4 columns]

# %%
#Reordenando o Dataframe em ordem decrescente
df_analise_grouped = df_analise_grouped.sort_values('VL_HOMOLOGADO-max',
                                                   ascending = False)

# %%
#Visualizando a ordem agrupada por Orgao e valor da licitacao (VL_LICITACAO-max)
df_analise_grouped
# Out:
#      CD_ORGAO  VL_HOMOLOGADO-mean  VL_HOMOLOGADO-min  VL_HOMOLOGADO-max
# 169     61000        6.634376e+07           23541.50       1.583767e+09
# 0         900        7.387836e+06              30.00       9.447200e+07
# 67      47000        8.011045e+06           33286.60       8.072894e+07
# 340     88258        4.194000e+07        41940000.00       4.194000e+07
# 206     66700        1.091403e+06            3180.00       3.128562e+07
# ..        ...                 ...                ...                ...
# 164     60101        2.192100e+03            2192.10       2.192100e+03
# 307     85401        2.112150e+03            2112.15       2.112150e+03
# 87      50001        1.995000e+03            1995.00       1.995000e+03
# 40      43800        4.230000e+02             423.00       4.230000e+02
# 114     54103        6.200000e+00               6.20       6.200000e+00
#
# [350 rows x 4 columns]

# %%
#Criando um grupo de analise com os 5 maiores gastos
#Encontrando os respectivos gastos com base em Valores Homologados para o 5 principais

df_analise_grouped_5 = df_analise_grouped.head()

# %%
#5 principais
df_analise_grouped_5
# Out:
#      CD_ORGAO  VL_HOMOLOGADO-mean  VL_HOMOLOGADO-min  VL_HOMOLOGADO-max
# 169     61000        6.634376e+07            23541.5       1.583767e+09
# 0         900        7.387836e+06               30.0       9.447200e+07
# 67      47000        8.011045e+06            33286.6       8.072894e+07
# 340     88258        4.194000e+07         41940000.0       4.194000e+07
# 206     66700        1.091403e+06             3180.0       3.128562e+07

# %%
#Encontrando atraves do códico os 5 de origem, atraves do pandas
#df_licitacao_2016[df_licitacao_2016['CD_ORGAO'] == 61000] --> PM DE TAPERA
#df_licitacao_2016[df_licitacao_2016['CD_ORGAO'] == 900] --> PROCURADORIA JUSTIÇA
#df_licitacao_2016[df_licitacao_2016['CD_ORGAO'] == 47000] --> PM DE HERVAL
#df_licitacao_2016[df_licitacao_2016['CD_ORGAO'] == 88258] --> CONS. PÚBLICO EXTREMO SUL
#df_licitacao_2016[df_licitacao_2016['CD_ORGAO'] == 66700] --> PM DE ELDORADO DO SUL

#Linha de código para buscar os dados anteriores no DataFrame "df_licitacao"
#df_licitacao[df_licitacao['CD_ORGAO'] == 66700]

# %%
#Criando um Plot de visualizacao com o valor maximo
#Justificativa: objetivo de estudo
# %matplotlib notebook
labels = ['PM DE TAPERA', 'PROCURADORIA JUSTIÇA', 'PM DE HERVAL', 'CONS. PÚBLICO EXTREMO SUL', 'PM DE ELDORADO DO SUL']
x = np.arange(len(labels))  
width = 0.25 
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, df_analise_grouped_5['VL_HOMOLOGADO-max'], 
                width, label = 'VL_HOMOLOGADO-max', color = 'turquoise')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.tick_params(axis = 'both', which = 'major', labelsize = 6)
ax.set_ylabel('VL_HOMOLOGADO-mean')
ax.legend()
ax.tick_params(axis='x', colors = 'black')
ax.tick_params(axis='y', colors = 'black')
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('black')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('black')
ax.grid(False)
fig.tight_layout()
plt.show()
plt.savefig('VL_HOMOLOGADO-max.png', dpi = 300)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Criando um Plot de visualizacao com o valor medio
#Justificativa: Visualizacao e interpretacao dos dados
# %matplotlib notebook
labels = ['PM DE TAPERA', 'PROCURADORIA JUSTIÇA', 'PM DE HERVAL', 'CONS. PÚBLICO EXTREMO SUL', 'PM DE ELDORADO DO SUL']
x = np.arange(len(labels))  
width = 0.25 
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, df_analise_grouped_5['VL_HOMOLOGADO-mean'], 
                width, label = 'VL_HOMOLOGADO-mean', color = 'mediumorchid')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.tick_params(axis = 'both', which = 'major', labelsize = 6)
ax.set_ylabel('VL_HOMOLOGADO-mean')
ax.legend()
ax.tick_params(axis='x', colors = 'black')
ax.tick_params(axis='y', colors = 'black')
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('black')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('black')
ax.grid(False)
fig.tight_layout()
plt.show()
plt.savefig('VL_HOMOLOGADO-mean.png', dpi = 300)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ---
#
# ### _*Discussão da análise dos dados numéricos*_
#
# A ideia inicial de agrupamento dos dados serviu para identificar os órgãos de maior influência em termos quantitativos, que foram: PM de Viamao, PM de POA, PM de Eldorado do Sul, Comusa e PM de Novo Cabrais.
#
#
# Com a presente identificação, pode-se ter uma padronização da área de maior exigência por itens isolodamente. Mas não implica diretamente em ser o ítem mais citado, a ser verificado pela análise NLP.
#
#
# ---

# %% [markdown]
# ---
# ###  _*Trabalhando com os dados categoricos - DS_OBJETO*_
#
# O intuito da presente analise seria verificar as areas de pedidos de licitacao.
# Identificar palavras mais relevantes que denotem areas.
#
#
# _*Aplicacao de NLP no DS_OBJETO*_
#
# Com isso, é necessário:
#
#  a) Avaliar a frequência das strings;
#
#  b) Determinar strings "curtas" e "longas";
#
#  c) Funcao (summarise) para encontrar caracteres;
#
#  d) Tokenizacao dos caracteres;
#
#  e) Stopwords;
#
#  e) n-gramas ou "n-grams".
#
# ---
#
# ---

# %%
#Criando o DataFrame de analise Categorica
df_categorico = df_licitacao[['CD_ORGAO', 'TP_OBJETO', 'DS_OBJETO']]
df_categorico
# Out:
#        CD_ORGAO TP_OBJETO                                          DS_OBJETO
# 0         53100       CSE  CONTRATAÇÃO GLOBAL DE EMPRESA PARA CONSTRUÇÃO ...
# 1         53100       OSE  Reforma da UBS do Distrito da Vila Cruz, pintu...
# 2         51802       PER  Constitui objeto da presente Licitação a explo...
# 3         84100       OUS  Contratação de serviços de arbitragem para atu...
# 4         86800       OUS  Contratação de empresa para prestação de servi...
# ...         ...       ...                                                ...
# 70541     58706       OUS  Elaboração de 01(um) cálculo atuarial referent...
# 70542     56900       COM            Fornecimento de passagem escolar urbana
# 70543     58701       CSE  Prestação de serviço de suporte técnico de man...
# 70544     88029       OUS  Contratação de empresa para pintura do prédio ...
# 70545     56900       COM  Aquisição de material educativo, esportivo e v...
#
# [70546 rows x 3 columns]

# %%
#Selecionando o Dataset apenas para o interesse do TP_OBJETO = COM
df_categorico = df_categorico.loc[df_categorico['TP_OBJETO'] == 'COM']
df_categorico
# Out:
#        CD_ORGAO TP_OBJETO                                          DS_OBJETO
# 5         45003       COM  Aquisição de 78.000 (setenta e oito mil) quilo...
# 6         45003       COM  Aquisição de 3.700 kg de polímero não iônico, ...
# 7         45003       COM  Aquisição de 65 t (sessenta e cindo toneladas)...
# 8         45003       COM  Aquisição de 40.500 (quarenta mil e quinhentos...
# 9         45003       COM  Aquisição de Larvicida biológico BTI (Bacillus...
# ...         ...       ...                                                ...
# 70537     82901       COM                  aquisição de materiais de limpeza
# 70538     82901       COM  aquisição de materiais de limpeza para esta ca...
# 70540      2304       COM  100.000 (cem mil) unidades munições CBC 40sw C...
# 70542     56900       COM            Fornecimento de passagem escolar urbana
# 70545     56900       COM  Aquisição de material educativo, esportivo e v...
#
# [22330 rows x 3 columns]

# %%
#Importando pacotes de processamento de linguagem natural NLP
import nltk
nltk.download('punkt') #token
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/viniciuspacheci/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/viniciuspacheci/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/viniciuspacheci/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
#Importando os pacotes necessarios para particao e analise
from sklearn.model_selection import train_test_split

#Processamento de texto e analise, diretamente do nltk
import re
from nltk import word_tokenize, sent_tokenize, FreqDist
from nltk.util import ngrams
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer

# %%
#Definindo o seed de execucao
seed = 123

# %%
#Definindo o Dataset de treino, apenas com a coluna de strings
#Justificativa: Criar um o dataset de interesse apenas com strings
X_train = df_categorico['DS_OBJETO']

# %%
#Realizando o "join" ou uniao de todas as strings dispostas na coluna DS_OBJETO
train_string = " ".join(X_train.values)
print(f"**** Extracao da train_string ***** \n{train_string[:101]}", "/n")
# Out:
# **** Extracao da train_string *****
# Aquisição de 78.000 (setenta e oito mil) quilogramas de antiespumante em base siliconada, bem como o  /n

# %%
#Etapa de remoção de acentuação

#Importacao do unicode
import unicodedata

#Criação de função para remoção de acentuação
def remove_acc(palavra):

    #Unicode normalize para transformação de equivalente na em latin
    nfkd = unicodedata.normalize('NFKD', palavra)
    palavraSemAcento = u"".join([c for c in nfkd if not unicodedata.combining(c)])

    #Retorno da palavra apenas com números, letras e espaço
    return re.sub('[^a-zA-Z0-9 \\\]', '', palavraSemAcento)

# %%
#Removendo a acentuação
#Optou-se, para o upload do notebook no Github, não retornar a função,
#por termos de visualização
#remove_acc(train_string)

# %%
#Realizando o split da Colecao do documento, frequentemente chamada de "Corpus"
splits = train_string.split()
print(f"**** Extracao dos splits ***** \n{splits[:18]}\n")
# Out:
# **** Extracao dos splits *****
# ['Aquisição', 'de', '78.000', '(setenta', 'e', 'oito', 'mil)', 'quilogramas', 'de', 'antiespumante', 'em', 'base', 'siliconada,', 'bem', 'como', 'o', 'fornecimento', 'dos']

# %%
#Verificando o conjunto das strings
#Optou-se, para o upload do notebook no Github, não retornar a função,
#por termos de visualização
#train_string

# %%
#Quantas strings há?
#Retornando os valores obtidos de strinds unificadas e valores unicos do conjunto
print(f"O numero de strings unificadas: {len(splits)}")
print(f"O numero de strings unicas: {len(set(splits))}")
# Out:
# O numero de strings unificadas: 420765
# O numero de strings unicas: 42225

# %%
#Encontrando as Strings com maior frequencia no DS_OBJETO
freq_splits = FreqDist(splits)
print(f"***** As 10 strings mais comumns no conjunto de dados DS_OBJETO: ***** /n {freq_splits.most_common(10)}", "/n")
# Out:
# ***** As 10 strings mais comumns no conjunto de dados DS_OBJETO: ***** /n [('de', 33107), ('DE', 21106), ('para', 11213), ('e', 10380), ('PARA', 7927), ('AQUISIÇÃO', 6912), ('Aquisição', 6574), ('E', 5227), ('da', 5047), ('do', 4849)] /n

# %%
#Definindo strings "curtas" (short) com até 5 caracteres
short = set(i for i in splits if len(i)<5)
short = [(i, freq_splits[i]) for i in short]
short.sort(key = lambda x:x[1], reverse = True)
#short

#Observa-se especialmente múltiplos unitários como km, e conectivos (tokens)

# %%
#Definindo strings "longas" (long) com mais de 18 letras
#Considerar, palavras longas com mais de 20 letras,
#de acordo com norma culta (https://www.normaculta.com.br/palavras-grandes/)
#Critério de análise selecionado para 18 letras.

long = set(i for i in splits if len(i)>18)
long = [(i, freq_splits[i]) for i in long]
long.sort(key = lambda x:x[1], reverse = True)
#long

#Observa-se a identificacao de Numeros de identificacao, como por exemplo
#de chassi de veiculos

# %%
#Criando uma funcao (summarise) para identificar o percentual da ocorrencia de certas strings:
#Como por exemplo "CHASSI", "MEDICAMENTOS"

def summarise(pattern, strings, freq):
    """Funcao summarise encontra o padrao inserido"""
    #Encontrando os "matches"
    compiled_pattern = re.compile(pattern)
    matches = [i for i in strings if compiled_pattern.search(i)]
    
    #Volume e proporcao dos "matches"
    print("{} strings, que sao {: .2%} do total".format(len(matches), len(matches)/len(strings)))
    
    #Criacao de listas de tuplas com os "matches" e as frequencias determinadas
    output = [(i, freq[i]) for i in set(matches)]
    output.sort(key = lambda x:x[1], reverse = True)
    
    return output

# %%
#Verificando algumas frequencias --> EQUIPAMENTOS
#Optou-se, para o upload do notebook no Github, não retornar a função,
#por termos de visualização
#summarise(r"EQUIPAMENTOS", splits, freq_splits)

# %%
#Verificando algumas frequencias --> FAMÍLIA
#Optou-se, para o upload do notebook no Github, não retornar a função,
#por termos de visualização
#summarise(r"FAMÍLIA", splits, freq_splits)

# %%
#Verificando frequencias de números
#Optou-se, para o upload do notebook no Github, não retornar a função,
#por termos de visualização
#summarise(r"\d", splits, freq_splits)

#Observa-se que estao presentes em ocasioes diversas,
#especialmente em identificacao

# %%
#Verificando a combinacao de palavras com pontuacoes diversas
#Justifica-se essa analise uma vez que nao há padrao na escrita
#Optou-se, para o upload do notebook no Github, não retornar a função,
#por termos de visualização
#summarise(r"\w+[_!&/~'-)(<\|}{\[\]]\w+", splits, freq_splits)

# %% [markdown]
# ---
# ##  Tokenizacao dos caracteres;
#
#  Necessária aplicacao de Tokenizacao para eliminar pontuacoes e afins;
#
#  Essencialmente para identificar quantos tokens existem e quantos tokens unicos existem;
#
#  Fonte: https://nlp.stanford.edu/IR-book/html/htmledition/tokenization-1.html;
#
# ---

# %%
#Aplicando o processo de Tokenizacao (tokenizer)
tokeniser = RegexpTokenizer("[A-Za-z]+")
tokens = tokeniser.tokenize(train_string)
print(tokens[:20], "\n")
# Out:
# ['Aquisi', 'o', 'de', 'setenta', 'e', 'oito', 'mil', 'quilogramas', 'de', 'antiespumante', 'em', 'base', 'siliconada', 'bem', 'como', 'o', 'fornecimento', 'dos', 'equipamentos', 'e']

# %%
#Com isso, podemos responder as questoes relevantes
print(f"O numero de tokens: {len(tokens)}")
print(f"O numero de tokens unicos: {len(set(tokens))}")
# Out:
# O numero de tokens: 484174
# O numero de tokens unicos: 22698

# %%
#Contudo, o numero de tokens é relativamente alto, um processo de normalizacao
#deve ser aplicado para padronizar letras maiúsculas e minúsculas (lower and upper cases)
#Para isso, utiliza-se o processo de lemmatization (agrupamento de formas flexionadas)
lemmatiser = WordNetLemmatizer()
tokens_norm = [lemmatiser.lemmatize(t.lower(), "v") for t in tokens]
print(f"O numero de tokens unicos é de: {len(set(tokens_norm))}")

#O numero de tokens reduziu de 4548 para 9738, aproximadamente 35%
# Out:
# O numero de tokens unicos é de: 15099

# %%
#Com isso, a analise decorre agora da analise dos tokens
#Analisando o "length" dos tokens e sua distribuicao

#Criacao de lista para o "length" de tokens
token_length = [len(t) for t in tokens]

#Numero médio de caracteres por token
print(f"Média de caracteres por token: {round(np.mean(token_length), 4)}")

#Plotando a distribuicao
# %matplotlib notebook
plt.figure(figsize = (8, 8))
sns.countplot(y = token_length)
plt.title("Extensão dos caracteres dos Tokens", size = 18)
plt.savefig('Token-Length.png', dpi = 300)

#Essa análise dos Tokens, é muito similar em termos de distribuição das anteriores, 
#identificando padrão ao longo dos anos.
# Out:
# Média de caracteres por token: 4.4909
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ---
# ##   Stopwords;
#
#   Identificacao de palavras que nao contribuem para o texto;
#
#   Por vezes sao conectivos e afins da linguagem;
#
#   Para as licitações, decidiu-se não acrescentar stopwords oriundas dos projetos e explorar os n-grams formados, podendo incluir stopwrods em seus contextos, especialmente os "five-grams".
#
# ---

# %%
#Criacao e verificacao das stopwords em Portugues
stop_words = stopwords.words("portuguese")
print(f"Há {len(stop_words)} stopwords.\n")
print(stop_words)
# Out:
# Há 204 stopwords.
#
# ['de', 'a', 'o', 'que', 'e', 'é', 'do', 'da', 'em', 'um', 'para', 'com', 'não', 'uma', 'os', 'no', 'se', 'na', 'por', 'mais', 'as', 'dos', 'como', 'mas', 'ao', 'ele', 'das', 'à', 'seu', 'sua', 'ou', 'quando', 'muito', 'nos', 'já', 'eu', 'também', 'só', 'pelo', 'pela', 'até', 'isso', 'ela', 'entre', 'depois', 'sem', 'mesmo', 'aos', 'seus', 'quem', 'nas', 'me', 'esse', 'eles', 'você', 'essa', 'num', 'nem', 'suas', 'meu', 'às', 'minha', 'numa', 'pelos', 'elas', 'qual', 'nós', 'lhe', 'deles', 'essas', 'esses', 'pelas', 'este', 'dele', 'tu', 'te', 'vocês', 'vos', 'lhes', 'meus', 'minhas', 'teu', 'tua', 'teus', 'tuas', 'nosso', 'nossa', 'nossos', 'nossas', 'dela', 'delas', 'esta', 'estes', 'estas', 'aquele', 'aquela', 'aqueles', 'aquelas', 'isto', 'aquilo', 'estou', 'está', 'estamos', 'estão', 'estive', 'esteve', 'estivemos', 'estiveram', 'estava', 'estávamos', 'estavam', 'estivera', 'estivéramos', 'esteja', 'estejamos', 'estejam', 'estivesse', 'estivéssemos', 'estivessem', 'estiver', 'estivermos', 'estiverem', 'hei', 'há', 'havemos', 'hão', 'houve', 'houvemos', 'houveram', 'houvera', 'houvéramos', 'haja', 'hajamos', 'hajam', 'houvesse', 'houvéssemos', 'houvessem', 'houver', 'houvermos', 'houverem', 'houverei', 'houverá', 'houveremos', 'houverão', 'houveria', 'houveríamos', 'houveriam', 'sou', 'somos', 'são', 'era', 'éramos', 'eram', 'fui', 'foi', 'fomos', 'foram', 'fora', 'fôramos', 'seja', 'sejamos', 'sejam', 'fosse', 'fôssemos', 'fossem', 'for', 'formos', 'forem', 'serei', 'será', 'seremos', 'serão', 'seria', 'seríamos', 'seriam', 'tenho', 'tem', 'temos', 'tém', 'tinha', 'tínhamos', 'tinham', 'tive', 'teve', 'tivemos', 'tiveram', 'tivera', 'tivéramos', 'tenha', 'tenhamos', 'tenham', 'tivesse', 'tivéssemos', 'tivessem', 'tiver', 'tivermos', 'tiverem', 'terei', 'terá', 'teremos', 'terão', 'teria', 'teríamos', 'teriam']

# %%
#Stopwords mais frequentes utilizadas
n_stopwords = len([t for t in tokens_norm if t in stop_words])
print(f"{n_stopwords} tokens são stopwords")
print(f"Isso corresponde a {round(100*n_stopwords/len(tokens_norm), 2)}%")
# Out:
# 185506 tokens são stopwords
# Isso corresponde a 38.31%

# %% [markdown]
# ---
# ##   n-gramas ou "n-grams";
#
#   Uso de n-grams para identificacao do conjunto de palavras mais relevantes;
#
#   Objetivando encontra a área de interesse mais frequente requisitada;
#
# ---

# %%
#Removendo as stopwords, para análise refinada dos n-grams
tokens_clean = [t for t in tokens_norm if t not in stop_words]
print(f"O número e tokens para análise dos n-grams é de: {len(tokens_clean)}")
print(f"Isso corresponde a redução de {round(100*len(tokens_clean)/len(tokens), 2)}% dos tokens originais")
# Out:
# O número e tokens para análise dos n-grams é de: 298668
# Isso corresponde a redução de 61.69% dos tokens originais

# %%
#Transforming X_train in DataFrame
X_train = pd.DataFrame(X_train)

# %%
#Com a remocao dos tokens, pode-se criar os n-grams: unigrams, bigrams, trigrams e fourgrams
#Com base na definicao das funcoes

def preprocess_text(text):
    """Pré-processamento do texto com tokens normalizados"""
    #Processo de "Tokenise"as palavras em modo alfabérico
    tokenizer = RegexpTokenizer(r'[A-Za-z]{2,}')
    tokens = tokenizer.tokenize(text)
    
    #Transformação em "lowercase" e processo de "lemmatise"
    lemmatiser = WordNetLemmatizer()
    lemmas = [lemmatiser.lemmatize(token.lower(), pos = 'v') for token in tokens]
    
    #Removendo stopwords
    keywords = [lemma for lemma in lemmas if lemma not in stop_words]
    return keywords

def get_frequent_ngram(corpus, ngram, n = 20):
    """Encontrando os n-grams mais comuns com os Tokens normalizados"""
    #Pré-processamento de cada documento
    documents = [preprocess_text(document) for document in corpus]
    
    #Encontrando n-grams por documento
    n_grams = [list(ngrams(document, ngram)) for document in documents]
    
    #Encontrando a frequência dos n-grams
    n_grams_flattened = [item for sublist in n_grams for item in sublist]
    freq_dist = FreqDist(n_grams_flattened)
    top_freq = freq_dist.most_common(n)
    return pd.DataFrame(top_freq, columns = ['ngram', 'count'])

"""
Optou-se por plotar individualmente, para melhor visualizacao
#Obtendo "uni", "bi", "tri" e "four-grams"
for i in range(1, 5):
    # %matplotlib notebook
    mapping = {1:"uni", 2:"bi", 3:"tri", 4:"four"}
    plt.figure(figsize=(25,15))
    sns.barplot(x = "count", y = "ngram",
data = get_frequent_ngram(X_train['DS_OBJETO'], i))
    plt.title(f"Mais comum {mapping[i]}grams")
    plt.savefig(f"Mais comum {mapping[i]}grams.png", dpi = 600"
"""
# Out:
# '\nOptou-se por plotar individualmente, para melhor visualizacao\n#Obtendo "uni", "bi", "tri" e "four-grams"\nfor i in range(1, 5):\n    %matplotlib notebook\n    mapping = {1:"uni", 2:"bi", 3:"tri", 4:"four"}\n    plt.figure(figsize=(25,15))\n    sns.barplot(x = "count", y = "ngram",\ndata = get_frequent_ngram(X_train[\'DS_OBJETO\'], i))\n    plt.title(f"Mais comum {mapping[i]}grams")\n    plt.savefig(f"Mais comum {mapping[i]}grams.png", dpi = 600"\n'

# %%
#Plotando uni-gram 
# %matplotlib notebook
mapping = {1:"uni"}
plt.figure(figsize=(10,10))
sns.barplot(x = "count", y = "ngram",
data = get_frequent_ngram(X_train['DS_OBJETO'], 1))
plt.title(f"Mais comum {mapping[1]}grams")
plt.savefig(f"Mais comum {mapping[1]}grams.png", dpi = 600)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
#Plotando bi-grams 
# %matplotlib notebook
mapping = {2:"bi"}
plt.figure(figsize=(15,10))
sns.barplot(x = "count", y = "ngram",
data = get_frequent_ngram(X_train['DS_OBJETO'], 2))
plt.title(f"Mais comum {mapping[2]}grams")
plt.savefig(f"Mais comum {mapping[2]}grams.png", dpi = 600)
# Out:
# <img src="data:image/png;base64,..." width="1500">

# %%
#Plotando tri-grams 
# %matplotlib notebook
mapping = {3:"tri"}
plt.figure(figsize=(25,10))
sns.barplot(x = "count", y = "ngram",
data = get_frequent_ngram(X_train['DS_OBJETO'], 3))
plt.title(f"Mais comum {mapping[3]}grams")
plt.savefig(f"Mais comum {mapping[3]}grams.png", dpi = 600)
# Out:
# <img src="data:image/png;base64,..." width="2500">

# %%
#Plotando four-grams
# %matplotlib notebook
mapping = {4:"four"}
plt.figure(figsize=(33,10))
sns.barplot(x = "count", y = "ngram",
data = get_frequent_ngram(X_train['DS_OBJETO'], 4))
plt.title(f"Mais comum {mapping[4]}grams")
plt.savefig(f"Mais comum {mapping[4]}grams.png", dpi = 600)
# Out:
# <img src="data:image/png;base64,..." width="3300">

# %%
#Plotando five-grams
# %matplotlib notebook
mapping = {5:"five"}
plt.figure(figsize=(40,10))
sns.barplot(x = "count", y = "ngram",
data = get_frequent_ngram(X_train['DS_OBJETO'], 5))
plt.title(f"Mais comum {mapping[5]}grams")
plt.savefig(f"Mais comum {mapping[5]}grams.png", dpi = 600)
# Out:
# <img src="data:image/png;base64,..." width="4000">

# %%
#Replotando o five-grams, sem formato de plot
data = get_frequent_ngram(X_train['DS_OBJETO'], 5)
data
# Out:
#                                                 ngram  count
# 0       (neros, aliment, cios, agricultura, familiar)    378
# 1         (aquisi, neros, aliment, cios, agricultura)    344
# 2       (registro, pre, seguintes, medicamentos, uso)    293
# 3         (pre, seguintes, medicamentos, uso, humano)    293
# 4      (sele, fornecedores, registro, pre, seguintes)    256
# 5   (fornecedores, registro, pre, seguintes, medic...    235
# 6            (conforme, especifica, es, anexo, condi)    234
# 7                  (especifica, es, anexo, condi, es)    234
# 8                  (es, anexo, condi, es, constantes)    233
# 9              (aquisi, bens, fam, lia, equipamentos)    225
# 10          (registro, pre, futura, eventual, aquisi)    224
# 11  (agricultura, familiar, empreendedor, familiar...    192
# 12               (es, constantes, termo, refer, ncia)    185
# 13  (seguintes, medicamentos, uso, humano, atendim...    176
# 14         (especifica, es, constantes, termo, refer)    175
# 15  (medicamentos, uso, humano, atendimento, demanda)    175
# 16      (conforme, especifica, es, constantes, termo)    173
# 17               (registro, pre, futuras, aquisi, es)    166
# 18      (uso, humano, atendimento, demanda, judicial)    161
# 19          (bens, fam, lia, equipamentos, materiais)    159

# %% [markdown]
# ---
# ##   Análise estatística dos produtos do NLP;
#
#   Objetivo de avalizacao dos tokens, caracteres, stopwords;
#
#   Esse recurso poderia ser melhor utilizado com agrupamento de categorias, como a questao a ser agrupada seria o CD_ORGAO, fica-se impossibilitado de plotar via grupos;
#
#   Estudo futuro poderia objetivar essa análise em grupos específicos.
#
# ---

# %%
#Criando métricas de análise para cada sentence e DS_OBJETO
#Responder: Qual o número de Tokens por documento?
#Qual a média de caracteres por documento?
#Qual a média de stopwrods por documento?
X_train["n_sentences"] = X_train['DS_OBJETO'].apply(sent_tokenize).apply(len)
X_train["tokens"] = X_train['DS_OBJETO'].apply(tokeniser.tokenize)
X_train["n_tokens"] = X_train["tokens"].apply(len)
X_train["n_characters"] = X_train['DS_OBJETO'].apply(len)
X_train["n_stopwords"] = X_train["tokens"].apply(lambda tokens: len([t for t in tokens if t in stop_words]))
X_train["p_stopwords"] = X_train["n_stopwords"]/X_train["n_tokens"]

# %%
#Replotando o conjunto de dados com as métricas
X_train
# Out:
#                                                DS_OBJETO  n_sentences  \
# 5      Aquisição de 78.000 (setenta e oito mil) quilo...            1
# 6      Aquisição de 3.700 kg de polímero não iônico, ...            1
# 7      Aquisição de 65 t (sessenta e cindo toneladas)...            2
# 8      Aquisição de 40.500 (quarenta mil e quinhentos...            1
# 9      Aquisição de Larvicida biológico BTI (Bacillus...            2
# ...                                                  ...          ...
# 70537                  aquisição de materiais de limpeza            1
# 70538  aquisição de materiais de limpeza para esta ca...            1
# 70540  100.000 (cem mil) unidades munições CBC 40sw C...            1
# 70542            Fornecimento de passagem escolar urbana            1
# 70545  Aquisição de material educativo, esportivo e v...            1
#
#                                                   tokens  n_tokens  \
# 5      [Aquisi, o, de, setenta, e, oito, mil, quilogr...        52
# 6      [Aquisi, o, de, kg, de, pol, mero, n, o, i, ni...        43
# 7      [Aquisi, o, de, t, sessenta, e, cindo, tonelad...        57
# 8      [Aquisi, o, de, quarenta, mil, e, quinhentos, ...        47
# 9      [Aquisi, o, de, Larvicida, biol, gico, BTI, Ba...        47
# ...                                                  ...       ...
# 70537            [aquisi, o, de, materiais, de, limpeza]         6
# 70538  [aquisi, o, de, materiais, de, limpeza, para, ...        10
# 70540  [cem, mil, unidades, muni, es, CBC, sw, CXPO, ...        13
# 70542      [Fornecimento, de, passagem, escolar, urbana]         5
# 70545  [Aquisi, o, de, material, educativo, esportivo...        10
#
#        n_characters  n_stopwords  p_stopwords
# 5               315           20     0.384615
# 6               221           15     0.348837
# 7               311           21     0.368421
# 8               284           15     0.319149
# 9               284           16     0.340426
# ...             ...          ...          ...
# 70537            33            3     0.500000
# 70538            60            5     0.500000
# 70540            81            0     0.000000
# 70542            39            1     0.200000
# 70545            67            4     0.400000
#
# [22330 rows x 7 columns]

# %%
#Analisando o "head()"
columns = ['DS_OBJETO', 'n_sentences', 'n_tokens', 'n_characters', 'n_stopwords', 'p_stopwords']
X_train[columns].head()
# Out:
#                                            DS_OBJETO  n_sentences  n_tokens  \
# 5  Aquisição de 78.000 (setenta e oito mil) quilo...            1        52
# 6  Aquisição de 3.700 kg de polímero não iônico, ...            1        43
# 7  Aquisição de 65 t (sessenta e cindo toneladas)...            2        57
# 8  Aquisição de 40.500 (quarenta mil e quinhentos...            1        47
# 9  Aquisição de Larvicida biológico BTI (Bacillus...            2        47
#
#    n_characters  n_stopwords  p_stopwords
# 5           315           20     0.384615
# 6           221           15     0.348837
# 7           311           21     0.368421
# 8           284           15     0.319149
# 9           284           16     0.340426

# %%
#Descrevendo estatisticamente o conjunto
X_train.describe()
# Out:
#         n_sentences      n_tokens  n_characters   n_stopwords   p_stopwords
# count  22330.000000  22330.000000  22330.000000  22330.000000  22330.000000
# mean       1.131975     21.682669    127.445678      5.146574      0.212539
# std        0.627282     20.207858    120.848071      7.702695      0.199195
# min        1.000000      1.000000      5.000000      0.000000      0.000000
# 25%        1.000000     10.000000     59.000000      0.000000      0.000000
# 50%        1.000000     17.000000     98.000000      3.000000      0.258621
# 75%        1.000000     27.000000    158.000000      8.000000      0.400000
# max       33.000000    364.000000   2000.000000    134.000000      0.714286

# %%
#Informacoes do conjunto de dados
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22330 entries, 5 to 70545
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   DS_OBJETO     22330 non-null  object
#  1   n_sentences   22330 non-null  int64
#  2   tokens        22330 non-null  object
#  3   n_tokens      22330 non-null  int64
#  4   n_characters  22330 non-null  int64
#  5   n_stopwords   22330 non-null  int64
#  6   p_stopwords   22330 non-null  float64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 1.4+ MB

# %%
#Agregando o conjunto de dados
num_vars = X_train.select_dtypes(np.number).columns
X_train.groupby("DS_OBJETO")[num_vars].agg(["mean", "median"])
# Out:
#                                                    n_sentences         \
#                                                           mean median
# DS_OBJETO
# \tAQUISIÇÃO DE MATERIAS UTILIZADOS PARA COBERTU...         1.0    1.0
# \tRegistro de Preços para aquisição de Água min...         1.0    1.0
#                     Constitui objeto da present...         1.0    1.0
#                     Constitui objeto da present...         1.0    1.0
#                     Constitui objeto da present...         1.0    1.0
# ...                                                        ...    ...
# “Aquisição gêneros alimentícios usados na meren...         1.0    1.0
# “Licitação pública de REGISTRO DE PREÇOS para a...         1.0    1.0
# “Licitação pública de REGISTRO DE PREÇOS para a...         1.0    1.0
# “Licitação pública para aquisição de alimentos ...         1.0    1.0
# “aquisição de veículo tipo furgoneta adaptado p...         1.0    1.0
#
#                                                    n_tokens         \
#                                                        mean median
# DS_OBJETO
# \tAQUISIÇÃO DE MATERIAS UTILIZADOS PARA COBERTU...     14.0   14.0
# \tRegistro de Preços para aquisição de Água min...     74.0   74.0
#                     Constitui objeto da present...     48.0   48.0
#                     Constitui objeto da present...    108.0  108.0
#                     Constitui objeto da present...     42.0   42.0
# ...                                                     ...    ...
# “Aquisição gêneros alimentícios usados na meren...     14.0   14.0
# “Licitação pública de REGISTRO DE PREÇOS para a...     41.0   41.0
# “Licitação pública de REGISTRO DE PREÇOS para a...     52.0   52.0
# “Licitação pública para aquisição de alimentos ...     36.0   36.0
# “aquisição de veículo tipo furgoneta adaptado p...     33.0   33.0
#
#                                                    n_characters         \
#                                                            mean median
# DS_OBJETO
# \tAQUISIÇÃO DE MATERIAS UTILIZADOS PARA COBERTU...         96.0   96.0
# \tRegistro de Preços para aquisição de Água min...        379.0  379.0
#                     Constitui objeto da present...        277.0  277.0
#                     Constitui objeto da present...        620.0  620.0
#                     Constitui objeto da present...        241.0  241.0
# ...                                                         ...    ...
# “Aquisição gêneros alimentícios usados na meren...         85.0   85.0
# “Licitação pública de REGISTRO DE PREÇOS para a...        211.0  211.0
# “Licitação pública de REGISTRO DE PREÇOS para a...        254.0  254.0
# “Licitação pública para aquisição de alimentos ...        191.0  191.0
# “aquisição de veículo tipo furgoneta adaptado p...        189.0  189.0
#
#                                                    n_stopwords         \
#                                                           mean median
# DS_OBJETO
# \tAQUISIÇÃO DE MATERIAS UTILIZADOS PARA COBERTU...         0.0    0.0
# \tRegistro de Preços para aquisição de Água min...        29.0   29.0
#                     Constitui objeto da present...        24.0   24.0
#                     Constitui objeto da present...        46.0   46.0
#                     Constitui objeto da present...        18.0   18.0
# ...                                                        ...    ...
# “Aquisição gêneros alimentícios usados na meren...         4.0    4.0
# “Licitação pública de REGISTRO DE PREÇOS para a...        15.0   15.0
# “Licitação pública de REGISTRO DE PREÇOS para a...        20.0   20.0
# “Licitação pública para aquisição de alimentos ...        14.0   14.0
# “aquisição de veículo tipo furgoneta adaptado p...        12.0   12.0
#
#                                                    p_stopwords
#                                                           mean    median
# DS_OBJETO
# \tAQUISIÇÃO DE MATERIAS UTILIZADOS PARA COBERTU...    0.000000  0.000000
# \tRegistro de Preços para aquisição de Água min...    0.391892  0.391892
#                     Constitui objeto da present...    0.500000  0.500000
#                     Constitui objeto da present...    0.425926  0.425926
#                     Constitui objeto da present...    0.428571  0.428571
# ...                                                        ...       ...
# “Aquisição gêneros alimentícios usados na meren...    0.285714  0.285714
# “Licitação pública de REGISTRO DE PREÇOS para a...    0.365854  0.365854
# “Licitação pública de REGISTRO DE PREÇOS para a...    0.384615  0.384615
# “Licitação pública para aquisição de alimentos ...    0.388889  0.388889
# “aquisição de veículo tipo furgoneta adaptado p...    0.363636  0.363636
#
# [20384 rows x 10 columns]

# %% [markdown]
# ---
# ###  _*Discussão da análise dos dados NLP*_
#
# Através do processamento NLP dos dados textuais, percebeu-se, através do processo dividido em multietapas, a identificação de áreas prioritárias como agricultura e setor alimentício. Com isso, o objetivo era identificar macroáreas de interesse nas licitações.
#
#
# Com a presente identificação, pode-se ter uma padronização da área de maior exigência por itens isolodamente. Mas não implica diretamente em ser o ítem mais citado, a ser verificado pela análise NLP.

# %% [markdown]
# ---
# ##  _*DISCUSSÕES E CONCLUSÕES- Ano 2019 - licitacoes.csv*_
#
#
#  De acordo com a análise exploratória submetida em duas etapas, para análise numérica e categórica, algumas conclusoes podem ser obtidas:
#
#  a) Em relação à análise via montante de Valor Homologado (VL_HOMOLOGADO), obteu-se resultados relevantes para elencar os 5 principais órgãos: PM de Tapera, Procuradoria da Justiça, PM de Herval, Cons. Público do Extremo Sul e PM de Eldorado do Sul. Justifica-se para o ano de 2019 em coerencia da análise e procedimento de "group by" e seleção de pares;
#
#  b) Em relação à análise NLP e os atributos oriundas da doluna DS_OBJETO, foi possível desenvolver uma análise exploratória com os principais domínios de processo NLP. Identificacao de tokens, de stopwords e n=grams. Com isso, observa-se, especialmente com base no "Mais comum fourgrams" que a aquisicao de alimentos e produtos alimentícios é a fonte de maior pedidos em termos de licitaçoes para o ano observado. O intuito da presente análise foi identificar "ramos" e não especificamente produtos;
#
#  c) Os primeiros n-grams (uni e bi) sugerem a existencia de palavras usais descrevendo "aquisicao", "registro", "municipio". Já uma análise com os n-grams (tri e four) permitem identificar dados padroes contundentes em relacao a áreas de pedidos de licitacao, com destaque para: "alimenticia", "agricultura" e "medicamentos de uso humano", ;
#
#  d) Com tais análises é possível identificar o padrao, através da análise exploratória dos pedidos solicitados pelos diversos órgaos do estado do Rio Grande do Sul. Em termos quantitativos e qualitativos.
#
# ---
