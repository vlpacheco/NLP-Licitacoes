# %% [markdown]
# # _*Exploratory-Data-Analysis-Year-2018*_

# %% [markdown]
# ---
# ##  _*1) Analise das Licitacoes - Ano 2018 - licitacoes.csv*_
#
# ---

# %% [markdown]
# ---
# ### _*Carregamento e identificacao dos dados*_
#  _*Secao destinada ao carregamento e analise inicial dos dados*_
#
#  _*Com isso, uma análise inicial de formato e tipo de variáveis é conduzido.*_
#
# ---

# %%
#Importanto as bibliotecas // Todos imports devem ser realizados aqui
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Carregabdo o dataset "licitacao.csv" 
df_licitacao = pd.read_csv('licitacao.csv')

#Visualizando as primeiras colunas
df_licitacao.head()
# Out:
# /Users/viniciuspacheci/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: DtypeWarning: Columns (52,53,54,55) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    CD_ORGAO                                       NM_ORGAO  NR_LICITACAO  \
# 0     45003  SERVIÇO AUTÔN. MUN. DE ÁGUA E ESGOTO - CX.SUL          82.0
# 1     45003  SERVIÇO AUTÔN. MUN. DE ÁGUA E ESGOTO - CX.SUL          54.0
# 2     45003  SERVIÇO AUTÔN. MUN. DE ÁGUA E ESGOTO - CX.SUL          90.0
# 3     45003  SERVIÇO AUTÔN. MUN. DE ÁGUA E ESGOTO - CX.SUL          11.0
# 4     45003  SERVIÇO AUTÔN. MUN. DE ÁGUA E ESGOTO - CX.SUL          43.0
#
#    ANO_LICITACAO CD_TIPO_MODALIDADE  NR_COMISSAO  ANO_COMISSAO TP_COMISSAO  \
# 0           2018                PRP      26258.0        2018.0           G
# 1           2018                PRP      26258.0        2018.0           G
# 2           2018                PRP      26258.0        2018.0           G
# 3           2018                PRP      25505.0        2017.0           G
# 4           2018                PRP      25505.0        2017.0           G
#
#   NR_PROCESSO  ANO_PROCESSO  ... TP_DOCUMENTO_FORNECEDOR  \
# 0       17685        2018.0  ...                     NaN
# 1       10315        2018.0  ...                     NaN
# 2       18979        2018.0  ...                     NaN
# 3        2679        2018.0  ...                     NaN
# 4        8059        2018.0  ...                     NaN
#
#   NR_DOCUMENTO_FORNECEDOR TP_DOCUMENTO_VENCEDOR NR_DOCUMENTO_VENCEDOR  \
# 0                     NaN                     J        07024978000132
# 1                     NaN                     J        05229392000189
# 2                     NaN                     J        87822110000117
# 3                     NaN                     J        87822110000117
# 4                     NaN                     J        87822110000117
#
#   VL_HOMOLOGADO BL_GERA_DESPESA DS_OBSERVACAO PC_TX_ESTIMADA PC_TX_HOMOLOGADA  \
# 0       89000.0               S           NaN            NaN              NaN
# 1     1560000.0               S           NaN            NaN              NaN
# 2      210000.0               S           NaN            NaN              NaN
# 3      120000.0               S           NaN            NaN              NaN
# 4      236925.0               S           NaN            NaN              NaN
#
#   BL_COMPARTILHADA
# 0                N
# 1                N
# 2                N
# 3                N
# 4                N
#
# [5 rows x 61 columns]

# %%
#Formato do dataset
print('Dataset shape is: {}' .format(df_licitacao.shape))
# Out:
# Dataset shape is: (73112, 61)

# %%
#Visualizando as informacoes e tipos de variaveis existentes
df_licitacao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73112 entries, 0 to 73111
# Data columns (total 61 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CD_ORGAO                     73112 non-null  int64
#  1   NM_ORGAO                     73112 non-null  object
#  2   NR_LICITACAO                 73112 non-null  float64
#  3   ANO_LICITACAO                73112 non-null  int64
#  4   CD_TIPO_MODALIDADE           73112 non-null  object
#  5   NR_COMISSAO                  46762 non-null  float64
#  6   ANO_COMISSAO                 46762 non-null  float64
#  7   TP_COMISSAO                  46762 non-null  object
#  8   NR_PROCESSO                  73050 non-null  object
#  9   ANO_PROCESSO                 73048 non-null  float64
#  10  TP_OBJETO                    73112 non-null  object
#  11  CD_TIPO_FASE_ATUAL           73112 non-null  object
#  12  TP_LICITACAO                 73112 non-null  object
#  13  TP_NIVEL_JULGAMENTO          73112 non-null  object
#  14  DT_AUTORIZACAO_ADESAO        643 non-null    object
#  15  TP_CARACTERISTICA_OBJETO     73112 non-null  object
#  16  TP_NATUREZA                  73112 non-null  object
#  17  TP_REGIME_EXECUCAO           15631 non-null  object
#  18  BL_PERMITE_SUBCONTRATACAO    49821 non-null  object
#  19  TP_BENEFICIO_MICRO_EPP       73112 non-null  object
#  20  TP_FORNECIMENTO              36098 non-null  object
#  21  TP_ATUACAO_REGISTRO          7823 non-null   object
#  22  NR_LICITACAO_ORIGINAL        726 non-null    object
#  23  ANO_LICITACAO_ORIGINAL       12617 non-null  float64
#  24  NR_ATA_REGISTRO_PRECO        720 non-null    object
#  25  DT_ATA_REGISTRO_PRECO        718 non-null    object
#  26  PC_TAXA_RISCO                15494 non-null  float64
#  27  TP_EXECUCAO                  23119 non-null  object
#  28  TP_DISPUTA                   197 non-null    object
#  29  TP_PREQUALIFICACAO           197 non-null    object
#  30  BL_INVERSAO_FASES            73112 non-null  object
#  31  TP_RESULTADO_GLOBAL          10976 non-null  object
#  32  CNPJ_ORGAO_GERENCIADOR       4670 non-null   float64
#  33  NM_ORGAO_GERENCIADOR         4668 non-null   object
#  34  DS_OBJETO                    73112 non-null  object
#  35  CD_TIPO_FUNDAMENTACAO        30809 non-null  object
#  36  NR_ARTIGO                    8760 non-null   float64
#  37  DS_INCISO                    2220 non-null   object
#  38  DS_LEI                       2243 non-null   object
#  39  DT_INICIO_INSCR_CRED         814 non-null    object
#  40  DT_FIM_INSCR_CRED            829 non-null    object
#  41  DT_INICIO_VIGEN_CRED         746 non-null    object
#  42  DT_FIM_VIGEN_CRED            745 non-null    object
#  43  VL_LICITACAO                 70043 non-null  float64
#  44  BL_ORCAMENTO_SIGILOSO        31735 non-null  object
#  45  BL_RECEBE_INSCRICAO_PER_VIG  6702 non-null   object
#  46  BL_PERMITE_CONSORCIO         73112 non-null  object
#  47  DT_ABERTURA                  73095 non-null  object
#  48  DT_HOMOLOGACAO               43850 non-null  object
#  49  DT_ADJUDICACAO               41514 non-null  object
#  50  BL_LICIT_PROPRIA_ORGAO       73112 non-null  object
#  51  TP_DOCUMENTO_FORNECEDOR      17995 non-null  object
#  52  NR_DOCUMENTO_FORNECEDOR      17995 non-null  object
#  53  TP_DOCUMENTO_VENCEDOR        5735 non-null   object
#  54  NR_DOCUMENTO_VENCEDOR        5735 non-null   object
#  55  VL_HOMOLOGADO                26636 non-null  object
#  56  BL_GERA_DESPESA              73112 non-null  object
#  57  DS_OBSERVACAO                2482 non-null   object
#  58  PC_TX_ESTIMADA               55 non-null     float64
#  59  PC_TX_HOMOLOGADA             41 non-null     float64
#  60  BL_COMPARTILHADA             73112 non-null  object
# dtypes: float64(11), int64(2), object(48)
# memory usage: 34.0+ MB

# %%
#Verificando o numero de colunas nulas
df_licitacao.isnull().sum()

#Muitas colunas com valores nulos, importante selecionar os termos de interesse da analise
# Out:
# CD_ORGAO                  0
# NM_ORGAO                  0
# NR_LICITACAO              0
# ANO_LICITACAO             0
# CD_TIPO_MODALIDADE        0
#                       ...
# BL_GERA_DESPESA           0
# DS_OBSERVACAO         70630
# PC_TX_ESTIMADA        73057
# PC_TX_HOMOLOGADA      73071
# BL_COMPARTILHADA          0
# Length: 61, dtype: int64

# %% [markdown]
# ---
# ###  _*Avaliando os dados numéricos*_
#  _*Avaliar tipos de variáveis e estrutura dos dados*_
#
# ---

# %%
#Verificando as colunas numericas
numeric_data = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

#Utilizacao do "select dtype" para encontrar valores numericos
numeric_df = df_licitacao.select_dtypes(include = numeric_data)

#Plotando colunas numericas
numeric_df
# Out:
#        CD_ORGAO  NR_LICITACAO  ANO_LICITACAO  NR_COMISSAO  ANO_COMISSAO  \
# 0         45003          82.0           2018      26258.0        2018.0
# 1         45003          54.0           2018      26258.0        2018.0
# 2         45003          90.0           2018      26258.0        2018.0
# 3         45003          11.0           2018      25505.0        2017.0
# 4         45003          43.0           2018      25505.0        2017.0
# ...         ...           ...            ...          ...           ...
# 73107     88370         107.0           2018          1.0        2018.0
# 73108     88370         110.0           2018          1.0        2018.0
# 73109     83700           2.0           2018        343.0        2017.0
# 73110      7400           1.0           2018         14.0        2017.0
# 73111     65300           1.0           2018       8704.0        2017.0
#
#        ANO_PROCESSO  ANO_LICITACAO_ORIGINAL  PC_TAXA_RISCO  \
# 0            2018.0                     NaN            NaN
# 1            2018.0                     NaN            NaN
# 2            2018.0                     NaN            NaN
# 3            2018.0                     NaN            NaN
# 4            2018.0                     NaN            NaN
# ...             ...                     ...            ...
# 73107        2017.0                     NaN            NaN
# 73108        2017.0                     NaN            NaN
# 73109        2018.0                     NaN            NaN
# 73110        2017.0                     NaN            NaN
# 73111        2018.0                     NaN            NaN
#
#        CNPJ_ORGAO_GERENCIADOR  NR_ARTIGO  VL_LICITACAO  PC_TX_ESTIMADA  \
# 0                         NaN        NaN     165244.46             NaN
# 1                         NaN        NaN    1596707.52             NaN
# 2                         NaN        NaN     828000.00             NaN
# 3                         NaN        NaN     231332.00             NaN
# 4                         NaN        NaN     398115.00             NaN
# ...                       ...        ...           ...             ...
# 73107                     NaN        NaN      34682.57             NaN
# 73108                     NaN        NaN     210000.00             NaN
# 73109                     NaN        NaN      78770.49             NaN
# 73110                     NaN        NaN      42330.00             NaN
# 73111                     NaN        NaN     124040.00             NaN
#
#        PC_TX_HOMOLOGADA
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 73107               NaN
# 73108               NaN
# 73109               NaN
# 73110               NaN
# 73111               NaN
#
# [73112 rows x 13 columns]

# %%
#Formato das colunas numericas
numeric_df.shape

#Valores numericos observado em 16 colunas e todas linhas do dataset
#Porem, há valores com "IDs", "Anos", "Numero de documento" e afins,
#que nao representam variaveis numericas e sim categoricas expressas
#em numeros
# Out:
# (73112, 13)

# %%
#Comprovando a nao linearidade dos valores numericos atraves da
#funcao de correlacao "corr()", por serem de fato categoricos
corr = numeric_df.corr()
corr.style.background_gradient(cmap='coolwarm') #Tentativa de plot, apenas para comprovacao
# Out:
# /Users/viniciuspacheci/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/style.py:2813: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# /Users/viniciuspacheci/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/style.py:2814: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_79465_row0_col0, #T_79465_row1_col1, #T_79465_row3_col3, #T_79465_row4_col4, #T_79465_row5_col5, #T_79465_row6_col6, #T_79465_row7_col7, #T_79465_row8_col8, #T_79465_row9_col9, #T_79465_row10_col10, #T_79465_row11_col11, #T_79465_row12_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_79465_row0_col1, #T_79465_row4_col1, #T_79465_row5_col1, #T_79465_row6_col4, #T_79465_row7_col1, #T_79465_row10_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_79465_row0_col2, #T_79465_row1_col2, #T_79465_row2_col0, #T_79465_row2_col1, #T_79465_row2_col2, #T_79465_row2_col3, #T_79465_row2_col4, #T_79465_row2_col5, #T_79465_row2_col6, #T_79465_row2_col7, #T_79465_row2_col8, #T_79465_row2_col9, #T_79465_row2_col10, #T_79465_row2_col11, #T_79465_row2_col12, #T_79465_row3_col2, #T_79465_row4_col2, #T_79465_row5_col2, #T_79465_row6_col2, #T_79465_row6_col7, #T_79465_row6_col11, #T_79465_row6_col12, #T_79465_row7_col2, #T_79465_row7_col6, #T_79465_row7_col8, #T_79465_row7_col9, #T_79465_row7_col11, #T_79465_row7_col12, #T_79465_row8_col2, #T_79465_row8_col7, #T_79465_row8_col12, #T_79465_row9_col2, #T_79465_row9_col7, #T_79465_row9_col11, #T_79465_row9_col12, #T_79465_row10_col2, #T_79465_row11_col2, #T_79465_row11_col6, #T_79465_row11_col7, #T_79465_row11_col9, #T_79465_row12_col2, #T_79465_row12_col6, #T_79465_row12_col7, #T_79465_row12_col8, #T_79465_row12_col9 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_79465_row0_col3, #T_79465_row7_col3, #T_79465_row10_col3 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_79465_row0_col4, #T_79465_row3_col9, #T_79465_row8_col1 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_79465_row0_col5, #T_79465_row1_col5, #T_79465_row6_col10, #T_79465_row7_col5, #T_79465_row10_col5 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_79465_row0_col6 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_79465_row0_col7, #T_79465_row3_col12, #T_79465_row12_col1 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_79465_row0_col8, #T_79465_row4_col0 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_79465_row0_col9, #T_79465_row1_col7, #T_79465_row3_col7, #T_79465_row5_col6, #T_79465_row5_col7, #T_79465_row6_col5, #T_79465_row8_col0, #T_79465_row8_col4, #T_79465_row8_col11, #T_79465_row10_col7, #T_79465_row10_col12, #T_79465_row11_col1, #T_79465_row11_col3, #T_79465_row11_col8, #T_79465_row12_col4, #T_79465_row12_col10 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_79465_row0_col10 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_79465_row0_col11 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_79465_row0_col12, #T_79465_row4_col12 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_79465_row1_col0, #T_79465_row3_col0, #T_79465_row5_col0 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_79465_row1_col3, #T_79465_row4_col3 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_79465_row1_col4, #T_79465_row5_col9, #T_79465_row10_col4 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_79465_row1_col6 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_79465_row1_col8 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_79465_row1_col9, #T_79465_row7_col4 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_79465_row1_col10, #T_79465_row3_col10, #T_79465_row4_col10, #T_79465_row6_col1, #T_79465_row7_col10 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_79465_row1_col11 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_79465_row1_col12, #T_79465_row12_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_79465_row3_col1, #T_79465_row9_col1 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_79465_row3_col4, #T_79465_row4_col9 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_79465_row3_col5, #T_79465_row4_col6 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_79465_row3_col6 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_79465_row3_col8 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_79465_row3_col11 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_79465_row4_col5, #T_79465_row5_col10 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_79465_row4_col7, #T_79465_row8_col3 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_79465_row4_col8 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_79465_row4_col11 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_79465_row5_col3, #T_79465_row9_col3 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_79465_row5_col4 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_79465_row5_col8, #T_79465_row6_col8 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_79465_row5_col11 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_79465_row5_col12 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_79465_row6_col0 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_79465_row6_col3 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_79465_row6_col9, #T_79465_row9_col4, #T_79465_row10_col9 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_79465_row7_col0, #T_79465_row10_col0 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_79465_row8_col5 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_79465_row8_col6 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_79465_row8_col9 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_79465_row8_col10 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_79465_row9_col0 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_79465_row9_col5, #T_79465_row9_col10, #T_79465_row10_col6 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_79465_row9_col6 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_79465_row9_col8 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_79465_row10_col8 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_79465_row10_col11 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_79465_row11_col0 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_79465_row11_col4, #T_79465_row11_col10 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_79465_row11_col5 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_79465_row11_col12 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_79465_row12_col0 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_79465_row12_col5 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_79465_row12_col11 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# </style>
# <table id="T_79465_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >CD_ORGAO</th>
#       <th class="col_heading level0 col1" >NR_LICITACAO</th>
#       <th class="col_heading level0 col2" >ANO_LICITACAO</th>
#       <th class="col_heading level0 col3" >NR_COMISSAO</th>
#       <th class="col_heading level0 col4" >ANO_COMISSAO</th>
#       <th class="col_heading level0 col5" >ANO_PROCESSO</th>
#       <th class="col_heading level0 col6" >ANO_LICITACAO_ORIGINAL</th>
#       <th class="col_heading level0 col7" >PC_TAXA_RISCO</th>
#       <th class="col_heading level0 col8" >CNPJ_ORGAO_GERENCIADOR</th>
#       <th class="col_heading level0 col9" >NR_ARTIGO</th>
#       <th class="col_heading level0 col10" >VL_LICITACAO</th>
#       <th class="col_heading level0 col11" >PC_TX_ESTIMADA</th>
#       <th class="col_heading level0 col12" >PC_TX_HOMOLOGADA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79465_level0_row0" class="row_heading level0 row0" >CD_ORGAO</th>
#       <td id="T_79465_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_79465_row0_col1" class="data row0 col1" >0.002256</td>
#       <td id="T_79465_row0_col2" class="data row0 col2" >nan</td>
#       <td id="T_79465_row0_col3" class="data row0 col3" >-0.000378</td>
#       <td id="T_79465_row0_col4" class="data row0 col4" >0.026651</td>
#       <td id="T_79465_row0_col5" class="data row0 col5" >-0.001122</td>
#       <td id="T_79465_row0_col6" class="data row0 col6" >0.022339</td>
#       <td id="T_79465_row0_col7" class="data row0 col7" >0.008503</td>
#       <td id="T_79465

# %% [markdown]
# ---
# ### _*Trabalhando com dados numericos - TP_OBJETO e VL_LICITADO*_
#
#  O intuito para o presente ano foi variar o VL_HOMOLOGADO para VL_LICITADO, conferindo a disponibilidade da coluna. Decidiu-se explorar também essa variável exclusivamente no ano 2018, por motivos exploratórios. Sabe-se que o valor solicitado difere, de fato do valor homologado. Porém, uma análise em conjunto de ambos poderia ser eficaz em processo de Feature Engineering e criação de um terceiro argumento com o % de aproveitamento entre licitado e homologado entre os municípios. Essa ideia de métrica, seria também uma sugestão para a continuidade do estudo.
#
# ---

# %%
#Selecao de variaveis para analise do VL_LICITACAO
#Identificacao das variaveis importantes para elencar licitacoes
#de acordo com o orgao

#Variaveis categoricas, representadas numericamente para analise
#CD_ORGAO --> Codigo do Orgao

#Justificativa: Analise numerica de relacao de valores por orgao.
#Analise do elemento com maior incidencia deve ser feito sob
#outra perspectiva

#Selecao também do requisito recomendado TP_OBJETO = COM
df_analise = df_licitacao[['CD_ORGAO', 'VL_LICITACAO', 'TP_OBJETO']]
df_analise
# Out:
#        CD_ORGAO  VL_LICITACAO TP_OBJETO
# 0         45003     165244.46       OUS
# 1         45003    1596707.52       CSE
# 2         45003     828000.00       COM
# 3         45003     231332.00       COM
# 4         45003     398115.00       COM
# ...         ...           ...       ...
# 73107     88370      34682.57       OUS
# 73108     88370     210000.00       OUS
# 73109     83700      78770.49       COM
# 73110      7400      42330.00       CSE
# 73111     65300     124040.00       COM
#
# [73112 rows x 3 columns]

# %%
#Criacao condicional do dataset, apenas dados de compra
df_analise = df_analise.loc[df_analise['TP_OBJETO'] == 'COM']

# %%
#Formato do novo dataset
print('Dataset shape is: {}' .format(df_analise.shape))
# Out:
# Dataset shape is: (24901, 3)

# %%
#Eliminacao de valor NaN na coluna VL_LICITACAO
df_analise = df_analise[df_analise['VL_LICITACAO'].notna()]

# %%
#Formato do novo dataset sem NaN 
print('Dataset shape is: {}' .format(df_analise.shape))
# Out:
# Dataset shape is: (22858, 3)

# %%
#Removendo valores iguais a zero
#Justificativa: Elementos com zero nao influenciam
#no resultado da analise
df_analise = df_analise[(df_analise != 0).all(1)]

# %%
#Formato do novo dataset sem zeros
print('Dataset shape is: {}' .format(df_analise.shape))
# Out:
# Dataset shape is: (21344, 3)

# %%
#Avaliando a distribuicao pelo histograma da variavel
#Observa-se forte distorcao nos dados e nao linearidade
#Ou seja, há valores exorbitantes e valores irrisórios
sns.distplot(df_analise['VL_LICITACAO'])
# Out:
# /Users/viniciuspacheci/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='VL_LICITACAO', ylabel='Density'>

# %%
#Avaliando através de estatistica descritiva a VL_LICITACAO
#Justifica-se o encontrado na distribuicao do histograma
df_analise['VL_LICITACAO'].describe()
# Out:
# count    2.134400e+04
# mean     1.105902e+06
# std      1.076475e+08
# min      1.000000e-01
# 25%      6.995750e+03
# 50%      3.023036e+04
# 75%      1.250000e+05
# max      1.569896e+10
# Name: VL_LICITACAO, dtype: float64

# %% [markdown]
# ---
# ###  _*Agrupando as colunas de interesse*_
#
# ####  _*Agrupando e calcular metricas basicas: min, ma e media (mean)*_
#
# ---

# %%
#Agrupando em forma de Multiindex as colunas
df_analise_grouped = df_analise.groupby('CD_ORGAO').agg({'VL_LICITACAO': ['mean',
                                                                         'min', 'max']})

# %%
#Renomeando as colunas, para nao trabalhar com multiindex

#Renomeando as colunas
df_analise_grouped.columns = ['VL_LICITACAO-mean', 'VL_LICITACAO-min', 'VL_LICITACAO-max']

#Resetando o index
df_analise_grouped = df_analise_grouped.reset_index()

# %%
#Replotando o DataFrame com as colunas renomeadas
df_analise_grouped
# Out:
#      CD_ORGAO  VL_LICITACAO-mean  VL_LICITACAO-min  VL_LICITACAO-max
# 0         100       2.266917e+05            361.26        6298436.29
# 1         200       4.351484e+04             25.52         714078.92
# 2         900       2.672552e+05            100.00        2992500.00
# 3        1005       8.927597e+04            238.80         740717.00
# 4        1400       1.964300e+05          79980.00         312879.90
# ..        ...                ...               ...               ...
# 693     88358       5.908280e+02            190.80           1471.00
# 694     88370       1.604546e+06              4.50       38688000.00
# 695     88374       1.131000e+03           1131.00           1131.00
# 696     88377       1.426256e+07       14262558.97       14262558.97
# 697     88379       4.194990e+03           4194.99           4194.99
#
# [698 rows x 4 columns]

# %%
#Reordenando o Dataframe em ordem decrescente
df_analise_grouped = df_analise_grouped.sort_values('VL_LICITACAO-max',
                                                   ascending = False)

# %%
#Visualizando a ordem agrupada por Orgao e valor da licitacao (VL_LICITACAO-max)
df_analise_grouped
# Out:
#      CD_ORGAO  VL_LICITACAO-mean  VL_LICITACAO-min  VL_LICITACAO-max
# 640     88044       1.706584e+08            693.25      1.569896e+10
# 674     88258       1.494623e+08            285.20      5.868022e+08
# 617     88004       5.282342e+06            129.99      3.783814e+08
# 692     88347       1.608099e+08       53304965.47      2.683149e+08
# 119     47000       3.493518e+06            118.90      1.385125e+08
# ..        ...                ...               ...               ...
# 216     54201       3.426667e+02            123.00      6.920000e+02
# 520     78202       3.093600e+02             60.00      5.587200e+02
# 269     57601       2.285200e+02            108.56      2.885000e+02
# 371     64601       1.916400e+02            191.64      1.916400e+02
# 168     50501       4.820000e+00              4.82      4.820000e+00
#
# [698 rows x 4 columns]

# %%
#Criando um grupo de analise com os 5 maiores gastos
#Encontrando os respectivos gastos com base em Valores Homologados para o 5 principais

df_analise_grouped_5 = df_analise_grouped.head()

# %%
#5 principais
df_analise_grouped_5
# Out:
#      CD_ORGAO  VL_LICITACAO-mean  VL_LICITACAO-min  VL_LICITACAO-max
# 640     88044       1.706584e+08            693.25      1.569896e+10
# 674     88258       1.494623e+08            285.20      5.868022e+08
# 617     88004       5.282342e+06            129.99      3.783814e+08
# 692     88347       1.608099e+08       53304965.47      2.683149e+08
# 119     47000       3.493518e+06            118.90      1.385125e+08

# %%
#Encontrando atraves do códico os 5 de origem, atraves do pandas
#df_licitacao[df_licitacao['CD_ORGAO'] == 88044] --> PM DE SANTA MARGADIDA DO SUL
#df_licitacao[df_licitacao['CD_ORGAO'] == 88258] --> CONS. PÚBICO DO EXTREMO SUL
#df_licitacao[df_licitacao['CD_ORGAO'] == 47000] --> SECRETARIA DA SAÚDE DO RS
#df_licitacao[df_licitacao['CD_ORGAO'] == 88258] --> CONS. PÚBLICO ASSOCIADOS
#df_licitacao[df_licitacao['CD_ORGAO'] == 47000] --> PM DE HERVAL

#Linha de código para buscar os dados anteriores no DataFrame "df_licitacao"
#df_licitacao[df_licitacao['CD_ORGAO'] == 66700]

# %%
#Criando um Plot de visualizacao com o valor maximo
#Justificativa: objetivo de estudo
# %matplotlib notebook
labels = ['PM DE ST. MARGADIDA DO SUL', 'CONS. PÚB.', 'SEC. DA SAÚDE', 'CONS. PÚB. ASSOCIADOS', 'PM DE HERVAL']
x = np.arange(len(labels))  
width = 0.25 
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, df_analise_grouped_5['VL_LICITACAO-max'], 
                width, label = 'VL_LICITACAO-max', color = 'turquoise')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.tick_params(axis = 'both', which = 'major', labelsize = 6)
ax.set_ylabel('VL_LICITACAO-mean')
ax.legend()
ax.tick_params(axis='x', colors = 'black')
ax.tick_params(axis='y', colors = 'black')
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('black')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('black')
ax.grid(False)
fig.tight_layout()
plt.show()
plt.savefig('VL_LICITACAO-max.png', dpi = 300)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Criando um Plot de visualizacao com o valor medio
#Justificativa: Visualizacao e interpretacao dos dados
# %matplotlib notebook
labels = ['PM DE ST. MARGADIDA DO SUL', 'CONS. PÚB.', 'SEC. DA SAÚDE', 'CONS. PÚB. ASSOCIADOS', 'PM DE HERVAL']
x = np.arange(len(labels))  
width = 0.25 
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, df_analise_grouped_5['VL_LICITACAO-mean'], 
                width, label = 'VL_LICITACAO-mean', color = 'mediumorchid')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.tick_params(axis = 'both', which = 'major', labelsize = 6)
ax.set_ylabel('VL_LICITACAO-mean')
ax.legend()
ax.tick_params(axis='x', colors = 'black')
ax.tick_params(axis='y', colors = 'black')
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('black')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('black')
ax.grid(False)
fig.tight_layout()
plt.show()
plt.savefig('VL_LICITACAO-mean.png', dpi = 300)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ---
#
# ###  _*Discussão da análise dos dados numéricos*_
#
# A ideia inicial de agrupamento dos dados serviu para identificar os órgãos de maior influência em termos quantitativos, que foram listados nos gráficos acima. Ressaltando que há a possibilidade de crição de métrica através do feature engineering entre as colunas VL_LICITADO e VL_HOMOLOGADO. O objetivo para o presente ano foi comprovar a capacidade de reprodução do mesmo processo analítico para a variável VL_LICITADO.
#
#
# ---

# %% [markdown]
# ---
# ### _*Trabalhando com os dados categoricos - DS_OBJETO*_
#
# O intuito da presente analise seria verificar as areas de pedidos de licitacao.
# Identificar palavras mais relevantes que denotem areas.
#
#
#  _*Aplicacao de NLP no DS_OBJETO*_
#
#  Com isso, é necessário:
#
#   a) Avaliar a frequência das strings;
#
#   b) Determinar strings "curtas" e "longas";
#
#   c) Funcao (summarise) para encontrar caracteres;
#
#   d) Tokenizacao dos caracteres;
#
#   e) Stopwords;
#
#   e) n-gramas ou "n-grams".
#
# ---
#
# ---

# %%
#Criando o DataFrame de analise Categorica
df_categorico = df_licitacao[['CD_ORGAO', 'TP_OBJETO', 'DS_OBJETO']]
df_categorico
# Out:
#        CD_ORGAO TP_OBJETO                                          DS_OBJETO
# 0         45003       OUS  Contratação de empresa para fornecimento de ma...
# 1         45003       CSE  Contratação de empresa para prestação de servi...
# 2         45003       COM  Aquisição de 60.000 kg (sessenta mil quilogram...
# 3         45003       COM  Aquisição de 40.000 kg (quarenta mil quilogram...
# 4         45003       COM  Aquisição de 40.500kg (quarenta mil e quinhent...
# ...         ...       ...                                                ...
# 73107     88370       OUS  Serviço de conserto de caminhonete marca Mitsu...
# 73108     88370       OUS  Serviços de seguro aeronáutico e transportador...
# 73109     83700       COM  REGISTRO DE PREÇOS PARA AQUISIÇÃO DE GÊNEROS A...
# 73110      7400       CSE  Contratação de empresa fornecedora de Software...
# 73111     65300       COM  Contratação de empresa(s) para o fornecimento ...
#
# [73112 rows x 3 columns]

# %%
#Selecionando o Dataset apenas para o interesse do TP_OBJETO = COM
df_categorico = df_categorico.loc[df_categorico['TP_OBJETO'] == 'COM']
df_categorico
# Out:
#        CD_ORGAO TP_OBJETO                                          DS_OBJETO
# 2         45003       COM  Aquisição de 60.000 kg (sessenta mil quilogram...
# 3         45003       COM  Aquisição de 40.000 kg (quarenta mil quilogram...
# 4         45003       COM  Aquisição de 40.500kg (quarenta mil e quinhent...
# 5         45003       COM  Aquisição de 65 t (sessenta e cindo toneladas)...
# 7         45003       COM  Aquisição de baterias estacionárias, para subs...
# ...         ...       ...                                                ...
# 73100     42200       COM  AQUISIÇÃO/INSTALAÇÃO DA AR CONDICIONADO NA MOT...
# 73101     78300       COM  Aquisição Parcelada de Gêneros Alimentícios pa...
# 73102     54912       COM            Aquisição de chave de impacto Shallper.
# 73109     83700       COM  REGISTRO DE PREÇOS PARA AQUISIÇÃO DE GÊNEROS A...
# 73111     65300       COM  Contratação de empresa(s) para o fornecimento ...
#
# [24901 rows x 3 columns]

# %%
#Importando pacotes de processamento de linguagem natural NLP
import nltk
nltk.download('punkt') #token
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/viniciuspacheci/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/viniciuspacheci/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/viniciuspacheci/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
#Importando os pacotes necessarios para particao e analise
from sklearn.model_selection import train_test_split

#Processamento de texto e analise, diretamente do nltk
import re
from nltk import word_tokenize, sent_tokenize, FreqDist
from nltk.util import ngrams
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer

# %%
#Definindo o seed de execucao
seed = 123

# %%
#Definindo o Dataset de treino, apenas com a coluna de strings
#Justificativa: Criar um o dataset de interesse apenas com strings
X_train = df_categorico['DS_OBJETO']

# %%
#Realizando o "join" ou uniao de todas as strings dispostas na coluna DS_OBJETO
train_string = " ".join(X_train.values)
print(f"**** Extracao da train_string ***** \n{train_string[:101]}", "/n")
# Out:
# **** Extracao da train_string *****
# Aquisição de 60.000 kg (sessenta mil quilogramas) de antiespumante em base siliconada, bem como o for /n

# %%
#Etapa de remoção de acentuação

#Importacao do unicode
import unicodedata

#Criação de função para remoção de acentuação
def remove_acc(palavra):

    #Unicode normalize para transformação de equivalente na em latin
    nfkd = unicodedata.normalize('NFKD', palavra)
    palavraSemAcento = u"".join([c for c in nfkd if not unicodedata.combining(c)])

    #Retorno da palavra apenas com números, letras e espaço
    return re.sub('[^a-zA-Z0-9 \\\]', '', palavraSemAcento)

# %%
#Removendo a acentuação
#optou-se pela não utilização da função no notebook a ser feito o upload
#no Github, por motivos de visualização
#remove_acc(train_string)

# %%
#Realizando o split da Colecao do documento, frequentemente chamada de "Corpus"
splits = train_string.split()
print(f"**** Extracao dos splits ***** \n{splits[:18]}\n")
# Out:
# **** Extracao dos splits *****
# ['Aquisição', 'de', '60.000', 'kg', '(sessenta', 'mil', 'quilogramas)', 'de', 'antiespumante', 'em', 'base', 'siliconada,', 'bem', 'como', 'o', 'fornecimento', 'dos', 'equipamentos']

# %%
#Verificando o conjunto das strings
#optou-se pela não utilização da função no notebook a ser feito o upload
#no Github, por motivos de visualização
#train_string

# %%
#Quantas strings há?
#Retornando os valores obtidos de strinds unificadas e valores unicos do conjunto
print(f"O numero de strings unificadas: {len(splits)}")
print(f"O numero de strings unicas: {len(set(splits))}")
# Out:
# O numero de strings unificadas: 457620
# O numero de strings unicas: 44850

# %%
#Encontrando as Strings com maior frequencia no DS_OBJETO
freq_splits = FreqDist(splits)
print(f"***** As 10 strings mais comumns no conjunto de dados DS_OBJETO: ***** /n {freq_splits.most_common(10)}", "/n")
# Out:
# ***** As 10 strings mais comumns no conjunto de dados DS_OBJETO: ***** /n [('de', 35197), ('DE', 24176), ('para', 11562), ('e', 10819), ('PARA', 8895), ('Aquisição', 8077), ('AQUISIÇÃO', 7782), ('E', 6410), ('da', 5326), ('do', 5227)] /n

# %%
#Definindo strings "curtas" (short) com até 5 caracteres
short = set(i for i in splits if len(i)<5)
short = [(i, freq_splits[i]) for i in short]
short.sort(key = lambda x:x[1], reverse = True)
#short

#Observa-se especialmente múltiplos unitários como km, e conectivos (tokens)

# %%
#Definindo strings "longas" (long) com mais de 18 letras
#Considerar, palavras longas com mais de 20 letras,
#de acordo com norma culta (https://www.normaculta.com.br/palavras-grandes/)
#Critério de análise selecionado para 18 letras.

long = set(i for i in splits if len(i)>18)
long = [(i, freq_splits[i]) for i in long]
long.sort(key = lambda x:x[1], reverse = True)
#long

#Observa-se a identificacao de Numeros de identificacao, como por exemplo
#de chassi de veiculos

# %%
#Criando uma funcao (summarise) para identificar o percentual da ocorrencia de certas strings:
#Como por exemplo "CHASSI", "MEDICAMENTOS"

def summarise(pattern, strings, freq):
    """Funcao summarise encontra o padrao inserido"""
    #Encontrando os "matches"
    compiled_pattern = re.compile(pattern)
    matches = [i for i in strings if compiled_pattern.search(i)]
    
    #Volume e proporcao dos "matches"
    print("{} strings, que sao {: .2%} do total".format(len(matches), len(matches)/len(strings)))
    
    #Criacao de listas de tuplas com os "matches" e as frequencias determinadas
    output = [(i, freq[i]) for i in set(matches)]
    output.sort(key = lambda x:x[1], reverse = True)
    
    return output

# %%
#Verificando algumas frequencias --> EQUIPAMENTOS
#optou-se pela não utilização da função no notebook a ser feito o upload
#no Github, por motivos de visualização
#summarise(r"EQUIPAMENTOS", splits, freq_splits)

# %%
#Verificando algumas frequencias --> FAMÍLIA
#optou-se pela não utilização da função no notebook a ser feito o upload
#no Github, por motivos de visualização
#summarise(r"FAMÍLIA", splits, freq_splits)

# %%
#Verificando frequencias de números
#optou-se pela não utilização da função no notebook a ser feito o upload
#no Github, por motivos de visualização
#summarise(r"\d", splits, freq_splits)

#Observa-se que estao presentes em ocasioes diversas,
#especialmente em identificacao

# %%
#Verificando a combinacao de palavras com pontuacoes diversas
#Justifica-se essa analise uma vez que nao há padrao na escrita
#optou-se pela não utilização da função no notebook a ser feito o upload
#no Github, por motivos de visualização
#summarise(r"\w+[_!&/~'-)(<\|}{\[\]]\w+", splits, freq_splits)

# %% [markdown]
# ---
# ##   Tokenizacao dos caracteres;
#
#   Necessária aplicacao de Tokenizacao para eliminar pontuacoes e afins;
#
#   Essencialmente para identificar quantos tokens existem e quantos tokens unicos existem;
#
#   Fonte: https://nlp.stanford.edu/IR-book/html/htmledition/tokenization-1.html;
#
# ---

# %%
#Aplicando o processo de Tokenizacao (tokenizer)
tokeniser = RegexpTokenizer("[A-Za-z]+")
tokens = tokeniser.tokenize(train_string)
print(tokens[:20], "\n")
# Out:
# ['Aquisi', 'o', 'de', 'kg', 'sessenta', 'mil', 'quilogramas', 'de', 'antiespumante', 'em', 'base', 'siliconada', 'bem', 'como', 'o', 'fornecimento', 'dos', 'equipamentos', 'e', 'materiais']

# %%
#Com isso, podemos responder as questoes relevantes
print(f"O numero de tokens: {len(tokens)}")
print(f"O numero de tokens unicos: {len(set(tokens))}")
# Out:
# O numero de tokens: 528433
# O numero de tokens unicos: 23757

# %%
#Contudo, o numero de tokens é relativamente alto, um processo de normalizacao
#deve ser aplicado para padronizar letras maiúsculas e minúsculas (lower and upper cases)
#Para isso, utiliza-se o processo de lemmatization (agrupamento de formas flexionadas)
lemmatiser = WordNetLemmatizer()
tokens_norm = [lemmatiser.lemmatize(t.lower(), "v") for t in tokens]
print(f"O numero de tokens unicos é de: {len(set(tokens_norm))}")

#O numero de tokens reduziu de 4548 para 9738, aproximadamente 35%
# Out:
# O numero de tokens unicos é de: 15665

# %%
#Com isso, a analise decorre agora da analise dos tokens
#Analisando o "length" dos tokens e sua distribuicao

#Criacao de lista para o "length" de tokens
token_length = [len(t) for t in tokens]

#Numero médio de caracteres por token
print(f"Média de caracteres por token: {round(np.mean(token_length), 4)}")

#Plotando a distribuicao
# %matplotlib notebook
plt.figure(figsize = (8, 8))
sns.countplot(y = token_length)
plt.title("Extensão dos caracteres dos Tokens", size = 18)
plt.savefig('Token-Length.png', dpi = 300)

#Essa análise dos Tokens, é muito similar em termos de distribuição das anteriores, 
#identificando padrão ao longo dos anos.
# Out:
# Média de caracteres por token: 4.4978
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ---
# ##  Stopwords;
#
#  Identificacao de palavras que nao contribuem para o texto;
#
#  Por vezes sao conectivos e afins da linguagem;
#
#  Para as licitações, decidiu-se não acrescentar stopwords oriundas dos projetos e explorar os n-grams formados, podendo incluir stopwrods em seus contextos, especialmente os "five-grams".
#
# ---

# %%
#Criacao e verificacao das stopwords em Portugues
stop_words = stopwords.words("portuguese")
print(f"Há {len(stop_words)} stopwords.\n")
print(stop_words)
# Out:
# Há 204 stopwords.
#
# ['de', 'a', 'o', 'que', 'e', 'é', 'do', 'da', 'em', 'um', 'para', 'com', 'não', 'uma', 'os', 'no', 'se', 'na', 'por', 'mais', 'as', 'dos', 'como', 'mas', 'ao', 'ele', 'das', 'à', 'seu', 'sua', 'ou', 'quando', 'muito', 'nos', 'já', 'eu', 'também', 'só', 'pelo', 'pela', 'até', 'isso', 'ela', 'entre', 'depois', 'sem', 'mesmo', 'aos', 'seus', 'quem', 'nas', 'me', 'esse', 'eles', 'você', 'essa', 'num', 'nem', 'suas', 'meu', 'às', 'minha', 'numa', 'pelos', 'elas', 'qual', 'nós', 'lhe', 'deles', 'essas', 'esses', 'pelas', 'este', 'dele', 'tu', 'te', 'vocês', 'vos', 'lhes', 'meus', 'minhas', 'teu', 'tua', 'teus', 'tuas', 'nosso', 'nossa', 'nossos', 'nossas', 'dela', 'delas', 'esta', 'estes', 'estas', 'aquele', 'aquela', 'aqueles', 'aquelas', 'isto', 'aquilo', 'estou', 'está', 'estamos', 'estão', 'estive', 'esteve', 'estivemos', 'estiveram', 'estava', 'estávamos', 'estavam', 'estivera', 'estivéramos', 'esteja', 'estejamos', 'estejam', 'estivesse', 'estivéssemos', 'estivessem', 'estiver', 'estivermos', 'estiverem', 'hei', 'há', 'havemos', 'hão', 'houve', 'houvemos', 'houveram', 'houvera', 'houvéramos', 'haja', 'hajamos', 'hajam', 'houvesse', 'houvéssemos', 'houvessem', 'houver', 'houvermos', 'houverem', 'houverei', 'houverá', 'houveremos', 'houverão', 'houveria', 'houveríamos', 'houveriam', 'sou', 'somos', 'são', 'era', 'éramos', 'eram', 'fui', 'foi', 'fomos', 'foram', 'fora', 'fôramos', 'seja', 'sejamos', 'sejam', 'fosse', 'fôssemos', 'fossem', 'for', 'formos', 'forem', 'serei', 'será', 'seremos', 'serão', 'seria', 'seríamos', 'seriam', 'tenho', 'tem', 'temos', 'tém', 'tinha', 'tínhamos', 'tinham', 'tive', 'teve', 'tivemos', 'tiveram', 'tivera', 'tivéramos', 'tenha', 'tenhamos', 'tenham', 'tivesse', 'tivéssemos', 'tivessem', 'tiver', 'tivermos', 'tiverem', 'terei', 'terá', 'teremos', 'terão', 'teria', 'teríamos', 'teriam']

# %%
#Stopwords mais frequentes utilizadas
n_stopwords = len([t for t in tokens_norm if t in stop_words])
print(f"{n_stopwords} tokens são stopwords")
print(f"Isso corresponde a {round(100*n_stopwords/len(tokens_norm), 2)}%")
# Out:
# 202893 tokens são stopwords
# Isso corresponde a 38.4%

# %% [markdown]
# ---
# ##   n-gramas ou "n-grams";
#
#   Uso de n-grams para identificacao do conjunto de palavras mais relevantes;
#
#   Objetivando encontra a área de interesse mais frequente requisitada;
#
# ---

# %%
#Removendo as stopwords, para análise refinada dos n-grams
tokens_clean = [t for t in tokens_norm if t not in stop_words]
print(f"O número e tokens para análise dos n-grams é de: {len(tokens_clean)}")
print(f"Isso corresponde a redução de {round(100*len(tokens_clean)/len(tokens), 2)}% dos tokens originais")
# Out:
# O número e tokens para análise dos n-grams é de: 325540
# Isso corresponde a redução de 61.6% dos tokens originais

# %%
#Transforming X_train in DataFrame
X_train = pd.DataFrame(X_train)

# %%
#Com a remocao dos tokens, pode-se criar os n-grams: unigrams, bigrams, trigrams e fourgrams
#Com base na definicao das funcoes

def preprocess_text(text):
    """Pré-processamento do texto com tokens normalizados"""
    #Processo de "Tokenise"as palavras em modo alfabérico
    tokenizer = RegexpTokenizer(r'[A-Za-z]{2,}')
    tokens = tokenizer.tokenize(text)
    
    #Transformação em "lowercase" e processo de "lemmatise"
    lemmatiser = WordNetLemmatizer()
    lemmas = [lemmatiser.lemmatize(token.lower(), pos = 'v') for token in tokens]
    
    #Removendo stopwords
    keywords = [lemma for lemma in lemmas if lemma not in stop_words]
    return keywords

def get_frequent_ngram(corpus, ngram, n = 20):
    """Encontrando os n-grams mais comuns com os Tokens normalizados"""
    #Pré-processamento de cada documento
    documents = [preprocess_text(document) for document in corpus]
    
    #Encontrando n-grams por documento
    n_grams = [list(ngrams(document, ngram)) for document in documents]
    
    #Encontrando a frequência dos n-grams
    n_grams_flattened = [item for sublist in n_grams for item in sublist]
    freq_dist = FreqDist(n_grams_flattened)
    top_freq = freq_dist.most_common(n)
    return pd.DataFrame(top_freq, columns = ['ngram', 'count'])

"""
Optou-se por plotar individualmente, para melhor visualizacao
#Obtendo "uni", "bi", "tri" e "four-grams"
for i in range(1, 5):
    # %matplotlib notebook
    mapping = {1:"uni", 2:"bi", 3:"tri", 4:"four"}
    plt.figure(figsize=(25,15))
    sns.barplot(x = "count", y = "ngram",
data = get_frequent_ngram(X_train['DS_OBJETO'], i))
    plt.title(f"Mais comum {mapping[i]}grams")
    plt.savefig(f"Mais comum {mapping[i]}grams.png", dpi = 600"
"""
# Out:
# '\nOptou-se por plotar individualmente, para melhor visualizacao\n#Obtendo "uni", "bi", "tri" e "four-grams"\nfor i in range(1, 5):\n    %matplotlib notebook\n    mapping = {1:"uni", 2:"bi", 3:"tri", 4:"four"}\n    plt.figure(figsize=(25,15))\n    sns.barplot(x = "count", y = "ngram",\ndata = get_frequent_ngram(X_train[\'DS_OBJETO\'], i))\n    plt.title(f"Mais comum {mapping[i]}grams")\n    plt.savefig(f"Mais comum {mapping[i]}grams.png", dpi = 600"\n'

# %%
#Plotando uni-gram 
# %matplotlib notebook
mapping = {1:"uni"}
plt.figure(figsize=(10,10))
sns.barplot(x = "count", y = "ngram",
data = get_frequent_ngram(X_train['DS_OBJETO'], 1))
plt.title(f"Mais comum {mapping[1]}grams")
plt.savefig(f"Mais comum {mapping[1]}grams.png", dpi = 600)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
#Plotando bi-grams 
# %matplotlib notebook
mapping = {2:"bi"}
plt.figure(figsize=(15,10))
sns.barplot(x = "count", y = "ngram",
data = get_frequent_ngram(X_train['DS_OBJETO'], 2))
plt.title(f"Mais comum {mapping[2]}grams")
plt.savefig(f"Mais comum {mapping[2]}grams.png", dpi = 600)
# Out:
# <img src="data:image/png;base64,..." width="1500">

# %%
#Plotando tri-grams 
# %matplotlib notebook
mapping = {3:"tri"}
plt.figure(figsize=(25,10))
sns.barplot(x = "count", y = "ngram",
data = get_frequent_ngram(X_train['DS_OBJETO'], 3))
plt.title(f"Mais comum {mapping[3]}grams")
plt.savefig(f"Mais comum {mapping[3]}grams.png", dpi = 600)
# Out:
# <img src="data:image/png;base64,..." width="2500">

# %%
#Plotando four-grams
# %matplotlib notebook
mapping = {4:"four"}
plt.figure(figsize=(33,10))
sns.barplot(x = "count", y = "ngram",
data = get_frequent_ngram(X_train['DS_OBJETO'], 4))
plt.title(f"Mais comum {mapping[4]}grams")
plt.savefig(f"Mais comum {mapping[4]}grams.png", dpi = 600)
# Out:
# <img src="data:image/png;base64,..." width="3300">

# %%
#Plotando five-grams
# %matplotlib notebook
mapping = {5:"five"}
plt.figure(figsize=(40,10))
sns.barplot(x = "count", y = "ngram",
data = get_frequent_ngram(X_train['DS_OBJETO'], 5))
plt.title(f"Mais comum {mapping[5]}grams")
plt.savefig(f"Mais comum {mapping[5]}grams.png", dpi = 600)
# Out:
# <img src="data:image/png;base64,..." width="4000">

# %%
#Replotando o five-grams, sem formato de plot
data = get_frequent_ngram(X_train['DS_OBJETO'], 5)
data
# Out:
#                                                 ngram  count
# 0       (neros, aliment, cios, agricultura, familiar)    406
# 1         (aquisi, neros, aliment, cios, agricultura)    358
# 2              (aquisi, bens, fam, lia, equipamentos)    303
# 3       (registro, pre, seguintes, medicamentos, uso)    262
# 4         (pre, seguintes, medicamentos, uso, humano)    262
# 5      (sele, fornecedores, registro, pre, seguintes)    251
# 6   (fornecedores, registro, pre, seguintes, medic...    240
# 7            (conforme, especifica, es, anexo, condi)    209
# 8                  (especifica, es, anexo, condi, es)    208
# 9                  (es, anexo, condi, es, constantes)    208
# 10  (agricultura, familiar, empreendedor, familiar...    198
# 11               (registro, pre, futuras, aquisi, es)    183
# 12          (bens, fam, lia, equipamentos, materiais)    181
# 13  (seguintes, medicamentos, uso, humano, atendim...    174
# 14  (medicamentos, uso, humano, atendimento, demanda)    174
# 15      (programa, nacional, alimenta, escolar, pnae)    161
# 16      (uso, humano, atendimento, demanda, judicial)    154
# 17   (aliment, cios, agricultura, familiar, alimenta)    152
# 18   (cios, agricultura, familiar, alimenta, escolar)    148
# 19  (aliment, cios, agricultura, familiar, empreen...    142

# %% [markdown]
# ---
# ##   Análise estatística dos produtos do NLP;
#
#   Objetivo de avalizacao dos tokens, caracteres, stopwords;
#
# ---

# %%
#Criando métricas de análise para cada sentence e DS_OBJETO
#Responder: Qual o número de Tokens por documento?
#Qual a média de caracteres por documento?
#Qual a média de stopwrods por documento?
X_train["n_sentences"] = X_train['DS_OBJETO'].apply(sent_tokenize).apply(len)
X_train["tokens"] = X_train['DS_OBJETO'].apply(tokeniser.tokenize)
X_train["n_tokens"] = X_train["tokens"].apply(len)
X_train["n_characters"] = X_train['DS_OBJETO'].apply(len)
X_train["n_stopwords"] = X_train["tokens"].apply(lambda tokens: len([t for t in tokens if t in stop_words]))
X_train["p_stopwords"] = X_train["n_stopwords"]/X_train["n_tokens"]

# %%
#Replotando o conjunto de dados com as métricas
X_train
# Out:
#                                                DS_OBJETO  n_sentences  \
# 2      Aquisição de 60.000 kg (sessenta mil quilogram...            1
# 3      Aquisição de 40.000 kg (quarenta mil quilogram...            2
# 4      Aquisição de 40.500kg (quarenta mil e quinhent...            1
# 5      Aquisição de 65 t (sessenta e cindo toneladas)...            2
# 7      Aquisição de baterias estacionárias, para subs...            1
# ...                                                  ...          ...
# 73100  AQUISIÇÃO/INSTALAÇÃO DA AR CONDICIONADO NA MOT...            1
# 73101  Aquisição Parcelada de Gêneros Alimentícios pa...            1
# 73102            Aquisição de chave de impacto Shallper.            1
# 73109  REGISTRO DE PREÇOS PARA AQUISIÇÃO DE GÊNEROS A...            1
# 73111  Contratação de empresa(s) para o fornecimento ...            1
#
#                                                   tokens  n_tokens  \
# 2      [Aquisi, o, de, kg, sessenta, mil, quilogramas...        65
# 3      [Aquisi, o, de, kg, quarenta, mil, quilogramas...        74
# 4      [Aquisi, o, de, kg, quarenta, mil, e, quinhent...        47
# 5      [Aquisi, o, de, t, sessenta, e, cindo, tonelad...        57
# 7      [Aquisi, o, de, baterias, estacion, rias, para...        23
# ...                                                  ...       ...
# 73100  [AQUISI, O, INSTALA, O, DA, AR, CONDICIONADO, ...        15
# 73101  [Aquisi, o, Parcelada, de, G, neros, Aliment, ...        28
# 73102      [Aquisi, o, de, chave, de, impacto, Shallper]         7
# 73109  [REGISTRO, DE, PRE, OS, PARA, AQUISI, O, DE, G...        13
# 73111  [Contrata, o, de, empresa, s, para, o, forneci...        19
#
#        n_characters  n_stopwords  p_stopwords
# 2               387           26     0.400000
# 3               438           28     0.378378
# 4               279           15     0.319149
# 5               313           21     0.368421
# 7               125           10     0.434783
# ...             ...          ...          ...
# 73100            98            0     0.000000
# 73101           160           10     0.357143
# 73102            39            3     0.428571
# 73109            64            0     0.000000
# 73111           117            9     0.473684
#
# [24901 rows x 7 columns]

# %%
#Analisando o "head()"
columns = ['DS_OBJETO', 'n_sentences', 'n_tokens', 'n_characters', 'n_stopwords', 'p_stopwords']
X_train[columns].head()
# Out:
#                                            DS_OBJETO  n_sentences  n_tokens  \
# 2  Aquisição de 60.000 kg (sessenta mil quilogram...            1        65
# 3  Aquisição de 40.000 kg (quarenta mil quilogram...            2        74
# 4  Aquisição de 40.500kg (quarenta mil e quinhent...            1        47
# 5  Aquisição de 65 t (sessenta e cindo toneladas)...            2        57
# 7  Aquisição de baterias estacionárias, para subs...            1        23
#
#    n_characters  n_stopwords  p_stopwords
# 2           387           26     0.400000
# 3           438           28     0.378378
# 4           279           15     0.319149
# 5           313           21     0.368421
# 7           125           10     0.434783

# %%
#Descrevendo estatisticamente o conjunto
X_train.describe()
# Out:
#         n_sentences      n_tokens  n_characters   n_stopwords   p_stopwords
# count  24901.000000  24901.000000  24901.000000  24901.000000  24879.000000
# mean       1.147625     21.221357    124.712020      4.893297      0.211219
# std        0.729233     20.908010    124.551306      7.563991      0.200844
# min        1.000000      0.000000      2.000000      0.000000      0.000000
# 25%        1.000000     10.000000     56.000000      0.000000      0.000000
# 50%        1.000000     16.000000     93.000000      2.000000      0.250000
# 75%        1.000000     26.000000    153.000000      8.000000      0.400000
# max       32.000000    368.000000   2000.000000    148.000000      0.750000

# %%
#Informacoes do conjunto de dados
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24901 entries, 2 to 73111
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   DS_OBJETO     24901 non-null  object
#  1   n_sentences   24901 non-null  int64
#  2   tokens        24901 non-null  object
#  3   n_tokens      24901 non-null  int64
#  4   n_characters  24901 non-null  int64
#  5   n_stopwords   24901 non-null  int64
#  6   p_stopwords   24879 non-null  float64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 1.5+ MB

# %%
#Agregando o conjunto de dados
num_vars = X_train.select_dtypes(np.number).columns
X_train.groupby("DS_OBJETO")[num_vars].agg(["mean", "median"])
# Out:
#                                                    n_sentences         \
#                                                           mean median
# DS_OBJETO
# \tAquisição de 01 cobertura em aluzinco, medind...         1.0    1.0
# \tAquisição de materiais cirúrgicos para Farmác...         1.0    1.0
#                                                ...         2.0    2.0
#                     Constitui objeto da present...         1.0    1.0
#                O presente projeto tem por objet...         1.0    1.0
# ...                                                        ...    ...
# “Aquisição de equipamentos e ferramentas, de ac...         1.0    1.0
# “Aquisição de gasolina, óleo diesel, óleo S10, ...         1.0    1.0
# “CONTRATAÇÃO DE EMPRESA PARA PRESTAÇÃO DE SERVI...         1.0    1.0
# “Licitação pública de REGISTRO DE PREÇOS para a...         1.0    1.0
# “Registro de Preços” para fornecimento de FORRA...         1.0    1.0
#
#                                                    n_tokens         \
#                                                        mean median
# DS_OBJETO
# \tAquisição de 01 cobertura em aluzinco, medind...     41.0   41.0
# \tAquisição de materiais cirúrgicos para Farmác...     17.0   17.0
#                                                ...     92.0   92.0
#                     Constitui objeto da present...     64.0   64.0
#                O presente projeto tem por objet...     25.0   25.0
# ...                                                     ...    ...
# “Aquisição de equipamentos e ferramentas, de ac...     59.0   59.0
# “Aquisição de gasolina, óleo diesel, óleo S10, ...     20.0   20.0
# “CONTRATAÇÃO DE EMPRESA PARA PRESTAÇÃO DE SERVI...     23.0   23.0
# “Licitação pública de REGISTRO DE PREÇOS para a...     37.0   37.0
# “Registro de Preços” para fornecimento de FORRA...     13.0   13.0
#
#                                                    n_characters         \
#                                                            mean median
# DS_OBJETO
# \tAquisição de 01 cobertura em aluzinco, medind...        254.0  254.0
# \tAquisição de materiais cirúrgicos para Farmác...         96.0   96.0
#                                                ...        640.0  640.0
#                     Constitui objeto da present...        366.0  366.0
#                O presente projeto tem por objet...        159.0  159.0
# ...                                                         ...    ...
# “Aquisição de equipamentos e ferramentas, de ac...        357.0  357.0
# “Aquisição de gasolina, óleo diesel, óleo S10, ...         98.0   98.0
# “CONTRATAÇÃO DE EMPRESA PARA PRESTAÇÃO DE SERVI...        119.0  119.0
# “Licitação pública de REGISTRO DE PREÇOS para a...        182.0  182.0
# “Registro de Preços” para fornecimento de FORRA...         80.0   80.0
#
#                                                    n_stopwords         \
#                                                           mean median
# DS_OBJETO
# \tAquisição de 01 cobertura em aluzinco, medind...        15.0   15.0
# \tAquisição de materiais cirúrgicos para Farmác...         6.0    6.0
#                                                ...        38.0   38.0
#                     Constitui objeto da present...        25.0   25.0
#                O presente projeto tem por objet...        10.0   10.0
# ...                                                        ...    ...
# “Aquisição de equipamentos e ferramentas, de ac...        23.0   23.0
# “Aquisição de gasolina, óleo diesel, óleo S10, ...         7.0    7.0
# “CONTRATAÇÃO DE EMPRESA PARA PRESTAÇÃO DE SERVI...         0.0    0.0
# “Licitação pública de REGISTRO DE PREÇOS para a...        13.0   13.0
# “Registro de Preços” para fornecimento de FORRA...         4.0    4.0
#
#                                                    p_stopwords
#                                                           mean    median
# DS_OBJETO
# \tAquisição de 01 cobertura em aluzinco, medind...    0.365854  0.365854
# \tAquisição de materiais cirúrgicos para Farmác...    0.352941  0.352941
#                                                ...    0.413043  0.413043
#                     Constitui objeto da present...    0.390625  0.390625
#                O presente projeto tem por objet...    0.400000  0.400000
# ...                                                        ...       ...
# “Aquisição de equipamentos e ferramentas, de ac...    0.389831  0.389831
# “Aquisição de gasolina, óleo diesel, óleo S10, ...    0.350000  0.350000
# “CONTRATAÇÃO DE EMPRESA PARA PRESTAÇÃO DE SERVI...    0.000000  0.000000
# “Licitação pública de REGISTRO DE PREÇOS para a...    0.351351  0.351351
# “Registro de Preços” para fornecimento de FORRA...    0.307692  0.307692
#
# [22423 rows x 10 columns]

# %% [markdown]
# ---
# ###  _*Discussão da análise dos dados NLP*_
#
# Observou-se para o presente ano, semelhanças em termos de padrões nos pedidos de solicitações, com referências principalmente, de acordo com os n-grams: alimentação, "pnae-programa nacional de alimentação escolar", agricultura, bens e equipamentos e medicamentos.

# %% [markdown]
# ---
# ## _*DISCUSSÕES E CONCLUSÕES- Ano 2016 - licitacoes.csv*_
#
#
#  De acordo com a análise exploratória submetida em duas etapas, para análise numérica e categórica, algumas conclusoes podem ser obtidas:
#
#  a) A presente análise quanto ao VL_LICITADO e a sugestão de criação de métrica suplementar para processo de Feature Engineering. A ideia consistiria em analisar o percentual de diferença entre as variáveis VL_HOMOLOGADO e VL_LICITADO. Criando assim uma métrica percentual em termos de aproveitamento de receita. Poderia ser útil na utilização futura e indicar padrões interessantes de análise;
#
#  b) Em relação à análise NLP áreas de interesse comuns e padronizadas com os anos anteriores (2016 e 2017) e também com o ano posterior como: alimentícia/alimentos, agricultura familiar e medicamentos, foram destacadas.
#
# ---
