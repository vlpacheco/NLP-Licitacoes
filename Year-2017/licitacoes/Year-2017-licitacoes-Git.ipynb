# %% [markdown]
# # _*Exploratory-Data-Analysis-Year-2017*_

# %% [markdown]
# ---
# ## _*1) Analise das Licitacoes - Ano 2017 - licitacoes.csv*_
#
# ---

# %% [markdown]
# ---
#
# ###  _*Carregamento e identificacao dos dados*_
#  _*Secao destinada ao carregamento e analise inicial dos dados*_
#
#  _*Com isso, uma análise inicial de formato e tipo de variáveis é conduzido.*_
#
# ---

# %%
#Importanto as bibliotecas // Todos imports devem ser realizados aqui
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Carregabdo o dataset "licitacao.csv" 
df_licitacao = pd.read_csv('licitacao.csv')

#Visualizando as primeiras colunas
df_licitacao.head()
# Out:
# /Users/viniciuspacheci/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: DtypeWarning: Columns (52,54) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    CD_ORGAO                                           NM_ORGAO  NR_LICITACAO  \
# 0     47500                               PM DE ESTÂNCIA VELHA          68.0
# 1     85900                                        PM DE TABAÍ           4.0
# 2     75300                                   PM DE DERRUBADAS           2.0
# 3     53411  INST. DE PREV. E ASSIST. DOS SERV. MUNIC. DE N...           1.0
# 4     88027                                PM DE CAPÃO DO CIPÓ           1.0
#
#    ANO_LICITACAO CD_TIPO_MODALIDADE  NR_COMISSAO  ANO_COMISSAO TP_COMISSAO  \
# 0           2017                PRP         16.0        2017.0           G
# 1           2017                PRD          NaN           NaN         NaN
# 2           2017                PRP        122.0        2016.0           G
# 3           2017                LEI         30.0        2016.0           G
# 4           2017                PRP        123.0        2017.0           G
#
#         NR_PROCESSO  ANO_PROCESSO  ... TP_DOCUMENTO_FORNECEDOR  \
# 0               144        2017.0  ...                     NaN
# 1                05        2017.0  ...                       J
# 2                 3        2017.0  ...                     NaN
# 3  2016.52.803139PA        2016.0  ...                     NaN
# 4                 1        2017.0  ...                     NaN
#
#   NR_DOCUMENTO_FORNECEDOR TP_DOCUMENTO_VENCEDOR NR_DOCUMENTO_VENCEDOR  \
# 0                     NaN                   NaN                   NaN
# 1        22148846000106.0                   NaN                   NaN
# 2                     NaN                   NaN                   NaN
# 3                     NaN                   NaN                   NaN
# 4                     NaN                   NaN                   NaN
#
#   VL_HOMOLOGADO BL_GERA_DESPESA DS_OBSERVACAO PC_TX_ESTIMADA PC_TX_HOMOLOGADA  \
# 0           NaN               S           NaN            NaN              NaN
# 1           NaN               S           NaN            NaN              NaN
# 2           NaN               S           NaN            NaN              NaN
# 3           NaN               S           NaN            NaN              NaN
# 4     1112500.0               S           NaN            NaN              NaN
#
#   BL_COMPARTILHADA
# 0                N
# 1                N
# 2                N
# 3                N
# 4                N
#
# [5 rows x 61 columns]

# %%
#Formato do dataset
print('Dataset shape is: {}' .format(df_licitacao.shape))
# Out:
# Dataset shape is: (62887, 61)

# %%
#Visualizando as informacoes e tipos de variaveis existentes
df_licitacao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62887 entries, 0 to 62886
# Data columns (total 61 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   CD_ORGAO                     62887 non-null  int64
#  1   NM_ORGAO                     62887 non-null  object
#  2   NR_LICITACAO                 62887 non-null  float64
#  3   ANO_LICITACAO                62887 non-null  int64
#  4   CD_TIPO_MODALIDADE           62887 non-null  object
#  5   NR_COMISSAO                  41977 non-null  float64
#  6   ANO_COMISSAO                 41977 non-null  float64
#  7   TP_COMISSAO                  41977 non-null  object
#  8   NR_PROCESSO                  62880 non-null  object
#  9   ANO_PROCESSO                 62880 non-null  float64
#  10  TP_OBJETO                    62887 non-null  object
#  11  CD_TIPO_FASE_ATUAL           62887 non-null  object
#  12  TP_LICITACAO                 62887 non-null  object
#  13  TP_NIVEL_JULGAMENTO          62887 non-null  object
#  14  DT_AUTORIZACAO_ADESAO        251 non-null    object
#  15  TP_CARACTERISTICA_OBJETO     62887 non-null  object
#  16  TP_NATUREZA                  62887 non-null  object
#  17  TP_REGIME_EXECUCAO           13026 non-null  object
#  18  BL_PERMITE_SUBCONTRATACAO    43565 non-null  object
#  19  TP_BENEFICIO_MICRO_EPP       62887 non-null  object
#  20  TP_FORNECIMENTO              35004 non-null  object
#  21  TP_ATUACAO_REGISTRO          6648 non-null   object
#  22  NR_LICITACAO_ORIGINAL        301 non-null    object
#  23  ANO_LICITACAO_ORIGINAL       11064 non-null  float64
#  24  NR_ATA_REGISTRO_PRECO        301 non-null    object
#  25  DT_ATA_REGISTRO_PRECO        300 non-null    object
#  26  PC_TAXA_RISCO                12332 non-null  float64
#  27  TP_EXECUCAO                  12589 non-null  object
#  28  TP_DISPUTA                   95 non-null     object
#  29  TP_PREQUALIFICACAO           76 non-null     object
#  30  BL_INVERSAO_FASES            62887 non-null  object
#  31  TP_RESULTADO_GLOBAL          9337 non-null   object
#  32  CNPJ_ORGAO_GERENCIADOR       1993 non-null   float64
#  33  NM_ORGAO_GERENCIADOR         1993 non-null   object
#  34  DS_OBJETO                    62887 non-null  object
#  35  CD_TIPO_FUNDAMENTACAO        24704 non-null  object
#  36  NR_ARTIGO                    7554 non-null   float64
#  37  DS_INCISO                    2601 non-null   object
#  38  DS_LEI                       2604 non-null   object
#  39  DT_INICIO_INSCR_CRED         708 non-null    object
#  40  DT_FIM_INSCR_CRED            713 non-null    object
#  41  DT_INICIO_VIGEN_CRED         652 non-null    object
#  42  DT_FIM_VIGEN_CRED            652 non-null    object
#  43  VL_LICITACAO                 61210 non-null  float64
#  44  BL_ORCAMENTO_SIGILOSO        26090 non-null  object
#  45  BL_RECEBE_INSCRICAO_PER_VIG  6289 non-null   object
#  46  BL_PERMITE_CONSORCIO         62887 non-null  object
#  47  DT_ABERTURA                  62880 non-null  object
#  48  DT_HOMOLOGACAO               36920 non-null  object
#  49  DT_ADJUDICACAO               35555 non-null  object
#  50  BL_LICIT_PROPRIA_ORGAO       62887 non-null  object
#  51  TP_DOCUMENTO_FORNECEDOR      14968 non-null  object
#  52  NR_DOCUMENTO_FORNECEDOR      14968 non-null  object
#  53  TP_DOCUMENTO_VENCEDOR        5118 non-null   object
#  54  NR_DOCUMENTO_VENCEDOR        5118 non-null   object
#  55  VL_HOMOLOGADO                23754 non-null  float64
#  56  BL_GERA_DESPESA              62887 non-null  object
#  57  DS_OBSERVACAO                2831 non-null   object
#  58  PC_TX_ESTIMADA               12 non-null     float64
#  59  PC_TX_HOMOLOGADA             11 non-null     float64
#  60  BL_COMPARTILHADA             62887 non-null  object
# dtypes: float64(12), int64(2), object(47)
# memory usage: 29.3+ MB

# %%
#Verificando o numero de colunas nulas
df_licitacao.isnull().sum()

#Muitas colunas com valores nulos, importante selecionar os termos de interesse da analise
# Out:
# CD_ORGAO                  0
# NM_ORGAO                  0
# NR_LICITACAO              0
# ANO_LICITACAO             0
# CD_TIPO_MODALIDADE        0
#                       ...
# BL_GERA_DESPESA           0
# DS_OBSERVACAO         60056
# PC_TX_ESTIMADA        62875
# PC_TX_HOMOLOGADA      62876
# BL_COMPARTILHADA          0
# Length: 61, dtype: int64

# %% [markdown]
# ---
# ###  _*Avaliando os dados numéricos*_
#  _*Avaliar tipos de variáveis e estrutura dos dados*_
#
# ---

# %%
#Verificando as colunas numericas
numeric_data = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

#Utilizacao do "select dtype" para encontrar valores numericos
numeric_df = df_licitacao.select_dtypes(include = numeric_data)

#Plotando colunas numericas
numeric_df
# Out:
#        CD_ORGAO  NR_LICITACAO  ANO_LICITACAO  NR_COMISSAO  ANO_COMISSAO  \
# 0         47500          68.0           2017         16.0        2017.0
# 1         85900           4.0           2017          NaN           NaN
# 2         75300           2.0           2017        122.0        2016.0
# 3         53411           1.0           2017         30.0        2016.0
# 4         88027           1.0           2017        123.0        2017.0
# ...         ...           ...            ...          ...           ...
# 62882     53302          10.0           2017          NaN           NaN
# 62883     63500           1.0           2017     482017.0        2017.0
# 62884     54907        1026.0           2017          NaN           NaN
# 62885     78200        6571.0           2017          NaN           NaN
# 62886     68701           1.0           2017          2.0        2018.0
#
#        ANO_PROCESSO  ANO_LICITACAO_ORIGINAL  PC_TAXA_RISCO  \
# 0            2017.0                     NaN            NaN
# 1            2017.0                     NaN            NaN
# 2            2017.0                     NaN            NaN
# 3            2016.0                     NaN            NaN
# 4            2017.0                     NaN            NaN
# ...             ...                     ...            ...
# 62882        2017.0                     NaN            NaN
# 62883        2017.0                     NaN            NaN
# 62884        2017.0                     NaN            NaN
# 62885        2017.0                     NaN            0.0
# 62886        2017.0                     NaN            NaN
#
#        CNPJ_ORGAO_GERENCIADOR  NR_ARTIGO  VL_LICITACAO  VL_HOMOLOGADO  \
# 0                         NaN        NaN      72691.16            NaN
# 1                         NaN        NaN       7966.70            NaN
# 2                         NaN        NaN      65808.91            NaN
# 3                         NaN        NaN       5800.00            NaN
# 4                         NaN        NaN    1058588.00      1112500.0
# ...                       ...        ...           ...            ...
# 62882                     NaN        NaN       8804.88            NaN
# 62883                     NaN        NaN     125970.00            NaN
# 62884                     NaN        NaN     226920.00            NaN
# 62885            9.430929e+13        NaN      33840.00            NaN
# 62886                     NaN        NaN      22524.84        20483.4
#
#        PC_TX_ESTIMADA  PC_TX_HOMOLOGADA
# 0                 NaN               NaN
# 1                 NaN               NaN
# 2                 NaN               NaN
# 3                 NaN               NaN
# 4                 NaN               NaN
# ...               ...               ...
# 62882             NaN               NaN
# 62883             NaN               NaN
# 62884             NaN               NaN
# 62885             NaN               NaN
# 62886             NaN               NaN
#
# [62887 rows x 14 columns]

# %%
#Formato das colunas numericas
numeric_df.shape

#Valores numericos observado em 16 colunas e todas linhas do dataset
#Porem, há valores com "IDs", "Anos", "Numero de documento" e afins,
#que nao representam variaveis numericas e sim categoricas expressas
#em numeros
# Out:
# (62887, 14)

# %%
#Comprovando a nao linearidade dos valores numericos atraves da
#funcao de correlacao "corr()", por serem de fato categoricos
corr = numeric_df.corr()
corr.style.background_gradient(cmap = 'coolwarm') #Tentativa de plot, apenas para comprovacao
# Out:
# /Users/viniciuspacheci/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/style.py:2813: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# /Users/viniciuspacheci/opt/anaconda3/lib/python3.8/site-packages/pandas/io/formats/style.py:2814: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_28b40_row0_col0, #T_28b40_row1_col1, #T_28b40_row3_col3, #T_28b40_row4_col4, #T_28b40_row5_col5, #T_28b40_row6_col6, #T_28b40_row8_col8, #T_28b40_row9_col9, #T_28b40_row10_col10, #T_28b40_row11_col11, #T_28b40_row12_col12, #T_28b40_row13_col13 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_28b40_row0_col1 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_28b40_row0_col2, #T_28b40_row0_col7, #T_28b40_row1_col2, #T_28b40_row1_col7, #T_28b40_row2_col0, #T_28b40_row2_col1, #T_28b40_row2_col2, #T_28b40_row2_col3, #T_28b40_row2_col4, #T_28b40_row2_col5, #T_28b40_row2_col6, #T_28b40_row2_col7, #T_28b40_row2_col8, #T_28b40_row2_col9, #T_28b40_row2_col10, #T_28b40_row2_col11, #T_28b40_row2_col12, #T_28b40_row2_col13, #T_28b40_row3_col2, #T_28b40_row3_col7, #T_28b40_row4_col2, #T_28b40_row4_col7, #T_28b40_row5_col2, #T_28b40_row5_col7, #T_28b40_row5_col12, #T_28b40_row5_col13, #T_28b40_row6_col2, #T_28b40_row6_col7, #T_28b40_row6_col12, #T_28b40_row6_col13, #T_28b40_row7_col0, #T_28b40_row7_col1, #T_28b40_row7_col2, #T_28b40_row7_col3, #T_28b40_row7_col4, #T_28b40_row7_col5, #T_28b40_row7_col6, #T_28b40_row7_col7, #T_28b40_row7_col8, #T_28b40_row7_col9, #T_28b40_row7_col10, #T_28b40_row7_col11, #T_28b40_row7_col12, #T_28b40_row7_col13, #T_28b40_row8_col2, #T_28b40_row8_col7, #T_28b40_row8_col12, #T_28b40_row8_col13, #T_28b40_row9_col2, #T_28b40_row9_col7, #T_28b40_row9_col12, #T_28b40_row9_col13, #T_28b40_row10_col2, #T_28b40_row10_col7, #T_28b40_row11_col2, #T_28b40_row11_col7, #T_28b40_row12_col2, #T_28b40_row12_col5, #T_28b40_row12_col6, #T_28b40_row12_col7, #T_28b40_row12_col8, #T_28b40_row12_col9, #T_28b40_row13_col2, #T_28b40_row13_col5, #T_28b40_row13_col6, #T_28b40_row13_col7, #T_28b40_row13_col8, #T_28b40_row13_col9 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_28b40_row0_col3 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_28b40_row0_col4, #T_28b40_row0_col10, #T_28b40_row8_col6 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_28b40_row0_col5 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_28b40_row0_col6, #T_28b40_row0_col8, #T_28b40_row0_col9, #T_28b40_row0_col11, #T_28b40_row1_col12, #T_28b40_row1_col13, #T_28b40_row5_col4, #T_28b40_row8_col0, #T_28b40_row8_col5, #T_28b40_row12_col10, #T_28b40_row13_col1, #T_28b40_row13_col3, #T_28b40_row13_col10 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_28b40_row0_col12 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_28b40_row0_col13 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_28b40_row1_col0 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_28b40_row1_col3, #T_28b40_row4_col3, #T_28b40_row10_col3, #T_28b40_row11_col3 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_28b40_row1_col4, #T_28b40_row11_col4 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_28b40_row1_col5, #T_28b40_row9_col5, #T_28b40_row10_col5 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_28b40_row1_col6 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_28b40_row1_col8, #T_28b40_row5_col0, #T_28b40_row8_col10 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_28b40_row1_col9, #T_28b40_row6_col9, #T_28b40_row8_col4, #T_28b40_row10_col9, #T_28b40_row11_col9 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_28b40_row1_col10, #T_28b40_row3_col10, #T_28b40_row4_col10, #T_28b40_row5_col8, #T_28b40_row5_col10, #T_28b40_row6_col0, #T_28b40_row9_col10 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_28b40_row1_col11, #T_28b40_row3_col4, #T_28b40_row3_col11, #T_28b40_row5_col11, #T_28b40_row6_col11, #T_28b40_row9_col11 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_28b40_row3_col0 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_28b40_row3_col1, #T_28b40_row5_col1, #T_28b40_row9_col1, #T_28b40_row10_col1, #T_28b40_row11_col1 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_28b40_row3_col5 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_28b40_row3_col6, #T_28b40_row11_col10 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_28b40_row3_col8 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_28b40_row3_col9 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_28b40_row3_col12, #T_28b40_row12_col3 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_28b40_row3_col13, #T_28b40_row12_col1 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_28b40_row4_col0 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_28b40_row4_col1 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_28b40_row4_col5 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_28b40_row4_col6, #T_28b40_row8_col11 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_28b40_row4_col8 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_28b40_row4_col9 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_28b40_row4_col11, #T_28b40_row5_col9, #T_28b40_row9_col4 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_28b40_row4_col12 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_28b40_row4_col13 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_28b40_row5_col3 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_28b40_row5_col6, #T_28b40_row6_col5 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_28b40_row6_col1 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_28b40_row6_col3 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_28b40_row6_col4, #T_28b40_row10_col6, #T_28b40_row10_col12 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_28b40_row6_col8 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_28b40_row6_col10, #T_28b40_row12_col0 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_28b40_row8_col1 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_28b40_row8_col3 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_28b40_row8_col9 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_28b40_row9_col0 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_28b40_row9_col3 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_28b40_row9_col6 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_28b40_row9_col8 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_28b40_row10_col0 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_28b40_row10_col4 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_28b40_row10_col8 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_28b40_row10_col11 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_28b40_row10_col13 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_28b40_row11_col0 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_28b40_row11_col5, #T_28b40_row11_col6 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_28b40_row11_col8 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_28b40_row11_col12 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_28b40_row11_col13 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_28b40_row12_col4 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_28b40_row12_col11 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_28b40_row12_col13, #T_28b40_row13_col12 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_28b40_row13_col0 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_28b40_row13_col4 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_28b40_row13_col11 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# </style>
# <table id="T_28b40_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >CD_ORGAO</th>
#       <th class="col_heading level0 col1" >NR_LICITACAO</th>
#       <th class="col_heading level0 col2" >ANO_LICITACAO</th>
#       <th class="col_heading level0 col3" >NR_COMISSAO</th>
#       <th class="col_heading level0 col4" >ANO_COMISSAO</th>
#       <th class="col_heading level0 col5" >ANO_PROCESSO</th>
#       <th class="col_heading level0 col6" >ANO_LICITACAO_ORIGINAL</th>
#       <th class="col_heading level0 col7" >PC_TAXA_RISCO</th>
#       <th class="col_heading level0 col8" >CNPJ_ORGAO_GERENCIADOR</th>
#       <th class="col_heading level

# %% [markdown]
# ---
# ###  _*Trabalhando com dados numericos - TP_OBJETO e VL_HOMOLOGADO*_
#
# O intuito da presente analise seria agrupar por valores os orgaoes e com isso identificar os IDs referentes aos maiores valores licitados. Tendo como premissa o VAL_HOMOLOGADO
#
# ---

# %%
#Selecao de variaveis para analise do VL_LICITACAO
#Identificacao das variaveis importantes para elencar licitacoes
#de acordo com o orgao

#Variaveis categoricas, representadas numericamente para analise
#CD_ORGAO --> Codigo do Orgao

#Justificativa: Analise numerica de relacao de valores por orgao.
#Analise do elemento com maior incidencia deve ser feito sob
#outra perspectiva

#Selecao também do requisito recomendado TP_OBJETO = COM
df_analise = df_licitacao[['CD_ORGAO', 'VL_HOMOLOGADO', 'TP_OBJETO']]
df_analise
# Out:
#        CD_ORGAO  VL_HOMOLOGADO TP_OBJETO
# 0         47500            NaN       OUS
# 1         85900            NaN       OUS
# 2         75300            NaN       COM
# 3         53411            NaN       ALB
# 4         88027      1112500.0       COM
# ...         ...            ...       ...
# 62882     53302            NaN       CSE
# 62883     63500            NaN       OSE
# 62884     54907            NaN       OUS
# 62885     78200            NaN       CSE
# 62886     68701        20483.4       LOC
#
# [62887 rows x 3 columns]

# %%
#Criacao condicional do dataset, apenas dados de compra
df_analise = df_analise.loc[df_analise['TP_OBJETO'] == 'COM']

# %%
#Formato do novo dataset
print('Dataset shape is: {}' .format(df_analise.shape))
# Out:
# Dataset shape is: (22625, 3)

# %%
#Eliminacao de valor NaN na coluna VL_HOMOLOGADO
df_analise = df_analise[df_analise['VL_HOMOLOGADO'].notna()]

# %%
#Formato do novo dataset sem NaN 
print('Dataset shape is: {}' .format(df_analise.shape))
# Out:
# Dataset shape is: (9687, 3)

# %%
#Removendo valores iguais a zero
#Justificativa: Elementos com zero nao influenciam
#no resultado da analise
df_analise = df_analise[(df_analise != 0).all(1)]

# %%
#Formato do novo dataset sem zeros
print('Dataset shape is: {}' .format(df_analise.shape))
# Out:
# Dataset shape is: (6991, 3)

# %%
#Avaliando a distribuicao pelo histograma da variavel
#Observa-se forte distorcao nos dados e nao linearidade
#Ou seja, há valores exorbitantes e valores irrisórios
sns.distplot(df_analise['VL_HOMOLOGADO'])
# Out:
# /Users/viniciuspacheci/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='VL_HOMOLOGADO', ylabel='Density'>

# %%
#Avaliando através de estatistica descritiva a VL_LICITACAO
#Justifica-se o encontrado na distribuicao do histograma
df_analise['VL_HOMOLOGADO'].describe()
# Out:
# count    6.991000e+03
# mean     2.774935e+05
# std      3.599988e+06
# min      1.000000e-02
# 25%      1.303333e+04
# 50%      3.900000e+04
# 75%      1.243170e+05
# max      2.517729e+08
# Name: VL_HOMOLOGADO, dtype: float64

# %% [markdown]
# ---
# ### _*Agrupando as colunas de interesse*_
#
# #### _*Agrupando e calcular metricas basicas: min, ma e media (mean)*_
#
# ---

# %%
#Agrupando em forma de Multiindex as colunas
df_analise_grouped = df_analise.groupby('CD_ORGAO').agg({'VL_HOMOLOGADO': ['mean',
                                                                         'min', 'max']})

# %%
#Renomeando as colunas, para nao trabalhar com multiindex

#Renomeando as colunas
df_analise_grouped.columns = ['VL_HOMOLOGADO-mean', 'VL_HOMOLOGADO-min', 'VL_HOMOLOGADO-max']

#Resetando o index
df_analise_grouped = df_analise_grouped.reset_index()

# %%
#Replotando o DataFrame com as colunas renomeadas
df_analise_grouped
# Out:
#      CD_ORGAO  VL_HOMOLOGADO-mean  VL_HOMOLOGADO-min  VL_HOMOLOGADO-max
# 0         900        2.184074e+05           32750.00           510000.0
# 1        1005        1.108113e+05           69900.00           161000.0
# 2        3400        1.954000e+04           19540.00            19540.0
# 3        4000        5.780216e+04           24100.00            85950.0
# 4        7100        4.842366e+05            1470.00          4509000.0
# ..        ...                 ...                ...                ...
# 444     88302        3.395400e+05          308720.00           370360.0
# 445     88309        5.000000e+04           50000.00            50000.0
# 446     88311        5.864807e+04           21536.64            95759.5
# 447     88326        1.060000e+05          106000.00           106000.0
# 448     88347        8.591108e+07        85911075.00         85911075.0
#
# [449 rows x 4 columns]

# %%
#Reordenando o Dataframe em ordem decrescente
df_analise_grouped = df_analise_grouped.sort_values('VL_HOMOLOGADO-max',
                                                   ascending = False)

# %%
#Visualizando a ordem agrupada por Orgao e valor da licitacao (VL_LICITACAO-max)
df_analise_grouped
# Out:
#      CD_ORGAO  VL_HOMOLOGADO-mean  VL_HOMOLOGADO-min  VL_HOMOLOGADO-max
# 82      47000        1.843168e+07           20000.00       2.517729e+08
# 49      44400        2.158135e+06            2454.00       9.117713e+07
# 448     88347        8.591108e+07        85911075.00       8.591108e+07
# 177     56400        5.937644e+06            9000.00       8.097499e+07
# 273     66700        9.691808e+05            1101.45       3.947434e+07
# ..        ...                 ...                ...                ...
# 127     52302        2.770050e+03            2770.05       2.770050e+03
# 154     54601        2.145230e+03            2145.23       2.145230e+03
# 202     58701        2.040000e+03            2040.00       2.040000e+03
# 158     54907        1.200000e+03            1200.00       1.200000e+03
# 288     69100        4.920000e+01              49.20       4.920000e+01
#
# [449 rows x 4 columns]

# %%
#Criando um grupo de analise com os 5 maiores gastos
#Encontrando os respectivos gastos com base em Valores Homologados para o 5 principais

df_analise_grouped_5 = df_analise_grouped.head()

# %%
#5 principais
df_analise_grouped_5
# Out:
#      CD_ORGAO  VL_HOMOLOGADO-mean  VL_HOMOLOGADO-min  VL_HOMOLOGADO-max
# 82      47000        1.843168e+07           20000.00       2.517729e+08
# 49      44400        2.158135e+06            2454.00       9.117713e+07
# 448     88347        8.591108e+07        85911075.00       8.591108e+07
# 177     56400        5.937644e+06            9000.00       8.097499e+07
# 273     66700        9.691808e+05            1101.45       3.947434e+07

# %%
#Encontrando atraves do códico os 5 de origem, atraves do pandas
#df_licitacao_2016[df_licitacao_2016['CD_ORGAO'] == 47000] --> PM DE HERVAL
#df_licitacao_2016[df_licitacao_2016['CD_ORGAO'] == 900] --> PM DE CANGAÇU
#df_licitacao_2016[df_licitacao_2016['CD_ORGAO'] == 88347] --> CONS. ASSOC. DOS MUNIC.
#df_licitacao_2016[df_licitacao_2016['CD_ORGAO'] == 56400] --> PM DE ROSÁRIO DO SUL
#df_licitacao_2016[df_licitacao_2016['CD_ORGAO'] == 66700] --> PM DE ELDORADO DO SUL

#Linha de código para buscar os dados anteriores no DataFrame "df_licitacao"
#df_licitacao[df_licitacao['CD_ORGAO'] == 66700]

# %%
#Criando um Plot de visualizacao com o valor maximo
#Justificativa: objetivo de estudo
# %matplotlib notebook
labels = ['PM DE HERVAL', 'PM DE CANGAÇU', 'CONS. ASSOC. DOS MUNIC.', 'PM DE ROSÁRIO DO SUL', 'PM DE ELDORADO DO SUL']
x = np.arange(len(labels))  
width = 0.25 
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, df_analise_grouped_5['VL_HOMOLOGADO-max'], 
                width, label = 'VL_HOMOLOGADO-max', color = 'turquoise')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.tick_params(axis = 'both', which = 'major', labelsize = 6)
ax.set_ylabel('VL_HOMOLOGADO-mean')
ax.legend()
ax.tick_params(axis='x', colors = 'black')
ax.tick_params(axis='y', colors = 'black')
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('black')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('black')
ax.grid(False)
fig.tight_layout()
plt.show()
plt.savefig('VL_HOMOLOGADO-max.png', dpi = 300)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#Criando um Plot de visualizacao com o valor medio
#Justificativa: Visualizacao e interpretacao dos dados
# %matplotlib notebook
labels = ['PM DE HERVAL', 'PM DE CANGAÇU', 'CONS. ASSOC. DOS MUNIC.', 'PM DE ROSÁRIO DO SUL', 'PM DE ELDORADO DO SUL']
x = np.arange(len(labels))  
width = 0.25 
fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, df_analise_grouped_5['VL_HOMOLOGADO-mean'], 
                width, label = 'VL_HOMOLOGADO-mean', color = 'mediumorchid')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.tick_params(axis = 'both', which = 'major', labelsize = 6)
ax.set_ylabel('VL_HOMOLOGADO-mean')
ax.legend()
ax.tick_params(axis='x', colors = 'black')
ax.tick_params(axis='y', colors = 'black')
ax.spines['right'].set_color('none')
ax.spines['left'].set_color('black')
ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('black')
ax.grid(False)
fig.tight_layout()
plt.show()
plt.savefig('VL_HOMOLOGADO-mean.png', dpi = 300)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ---
#
# ###  _*Discussão da análise dos dados numéricos*_
#
# Observa-se para o presente ano uma distribuição com grau de homogeneidade maior em relação às anteriores. Há também indicativos de rotatividade entre os órgãos com maiores volumes de licitações, ou seja, há diversidade entre os que figuram as 5 primeiras posições. Com isso, apesar da heterogeneidade do "ranking" dos 5 primeiros em termos de volume homologado, alguns órgãos tem sua frequência constante, como o caso da PM de Eldorado do Sul.
#
#
# Com a presente identificação, pode-se ter uma padronização da área de maior exigência por itens isolodamente. Mas não implica diretamente em ser o ítem mais citado, a ser verificado pela análise NLP.
#
#
# ---

# %% [markdown]
# ---
# ###  _*Trabalhando com os dados categoricos - DS_OBJETO*_
#
# O intuito da presente analise seria verificar as areas de pedidos de licitacao.
# Identificar palavras mais relevantes que denotem areas.
#
#
#  _*Aplicacao de NLP no DS_OBJETO*_
#
#  Com isso, é necessário:
#
#   a) Avaliar a frequência das strings;
#
#   b) Determinar strings "curtas" e "longas";
#
#   c) Funcao (summarise) para encontrar caracteres;
#
#   d) Tokenizacao dos caracteres;
#
#   e) Stopwords;
#
#   e) n-gramas ou "n-grams".
#
# ---
#
# ---

# %%
#Criando o DataFrame de analise Categorica
df_categorico = df_licitacao[['CD_ORGAO', 'TP_OBJETO', 'DS_OBJETO']]
df_categorico
# Out:
#        CD_ORGAO TP_OBJETO                                          DS_OBJETO
# 0         47500       OUS  CONTRATAÇÃO, EXCLUSIVA PARA EMPRESAS BENEFICIÁ...
# 1         85900       OUS  CONTRATAÇÃO DE EMPRESA PARA PRESTAR SERVIÇOS D...
# 2         75300       COM                            Aquisição de alimentos.
# 3         53411       ALB               VEÍCULO MICROÔNIBUS KIA BESTA 12P GS
# 4         88027       COM  AQUISIÇÃO DE COMBUSTIVEIS PARA MANUTENÇÃO DA F...
# ...         ...       ...                                                ...
# 62882     53302       CSE  CONTRATAÇÃO EMPRESA PARA PRESTAÇÃO DE SERVIÇOS...
# 62883     63500       OSE  CONTRATACAO DE EMPRESA PARA CONSTRUCAO DE 80 T...
# 62884     54907       OUS  Contratação de serviço de suporte técnico e ma...
# 62885     78200       CSE             Locação de imóvel para a sede da SMDUH
# 62886     68701       LOC  LOCAÇÃO E MANUTENÇÃO DE SOFTWARE/SISTEMA DE IN...
#
# [62887 rows x 3 columns]

# %%
#Selecionando o Dataset apenas para o interesse do TP_OBJETO = COM
df_categorico = df_categorico.loc[df_categorico['TP_OBJETO'] == 'COM']
df_categorico
# Out:
#        CD_ORGAO TP_OBJETO                                          DS_OBJETO
# 2         75300       COM                            Aquisição de alimentos.
# 4         88027       COM  AQUISIÇÃO DE COMBUSTIVEIS PARA MANUTENÇÃO DA F...
# 20        72300       COM  "AQUISIÇÃO DE PNEU/CÂMARA/ COLARINHO NOVOS PAR...
# 24        81000       COM                   Aquisição de óleos lubrificantes
# 25        42200       COM  CONTRATAÇÃO DE EMPRESA PARA FORNECIMENTO DE CO...
# ...         ...       ...                                                ...
# 62840     62100       COM                            Aquisição de camisetas.
# 62847     59500       COM  Aquisição de GÊNEROS ALIMENTÍCIOS DA AGRICULTU...
# 62848     59500       COM  Aquisição de GÊNEROS ALIMENTÍCIOS DA AGRICULTU...
# 62860     54800       COM  Aquisição de gêneros alimentícios da Agricultu...
# 62877     44500       COM                           WORKSTATION HP INC Z 440
#
# [22625 rows x 3 columns]

# %%
#Importando pacotes de processamento de linguagem natural NLP
import nltk
nltk.download('punkt') #token
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/viniciuspacheci/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/viniciuspacheci/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/viniciuspacheci/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
#Importando os pacotes necessarios para particao e analise
from sklearn.model_selection import train_test_split

#Processamento de texto e analise, diretamente do nltk
import re
from nltk import word_tokenize, sent_tokenize, FreqDist
from nltk.util import ngrams
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import RegexpTokenizer

# %%
#Definindo o seed de execucao
seed = 123

# %%
#Definindo o Dataset de treino, apenas com a coluna de strings
#Justificativa: Criar um o dataset de interesse apenas com strings
X_train = df_categorico['DS_OBJETO']

# %%
#Realizando o "join" ou uniao de todas as strings dispostas na coluna DS_OBJETO
train_string = " ".join(X_train.values)
print(f"**** Extracao da train_string ***** \n{train_string[:101]}", "/n")
# Out:
# **** Extracao da train_string *****
# Aquisição de alimentos. AQUISIÇÃO DE COMBUSTIVEIS PARA MANUTENÇÃO DA FROTA MUNICIPAL "AQUISIÇÃO DE PN /n

# %%
#Etapa de remoção de acentuação

#Importacao do unicode
import unicodedata

#Criação de função para remoção de acentuação
def remove_acc(palavra):

    #Unicode normalize para transformação de equivalente na em latin
    nfkd = unicodedata.normalize('NFKD', palavra)
    palavraSemAcento = u"".join([c for c in nfkd if not unicodedata.combining(c)])

    #Retorno da palavra apenas com números, letras e espaço
    return re.sub('[^a-zA-Z0-9 \\\]', '', palavraSemAcento)

# %%
#Removendo a acentuação
#Optou-se pela não execução da célula ao fazer o upload no GitHub,
#pelo motivo da extensão das strings geradas.
#remove_acc(train_string)

# %%
#Realizando o split da Colecao do documento, frequentemente chamada de "Corpus"
splits = train_string.split()
print(f"**** Extracao dos splits ***** \n{splits[:18]}\n")
# Out:
# **** Extracao dos splits *****
# ['Aquisição', 'de', 'alimentos.', 'AQUISIÇÃO', 'DE', 'COMBUSTIVEIS', 'PARA', 'MANUTENÇÃO', 'DA', 'FROTA', 'MUNICIPAL', '"AQUISIÇÃO', 'DE', 'PNEU/CÂMARA/', 'COLARINHO', 'NOVOS', 'PARA', 'A']

# %%
#Verificando o conjunto das strings
#train_string

# %%
#Quantas strings há?
#Retornando os valores obtidos de strinds unificadas e valores unicos do conjunto
print(f"O numero de strings unificadas: {len(splits)}")
print(f"O numero de strings unicas: {len(set(splits))}")
# Out:
# O numero de strings unificadas: 399782
# O numero de strings unicas: 37413

# %%
#Encontrando as Strings com maior frequencia no DS_OBJETO
freq_splits = FreqDist(splits)
print(f"***** As 10 strings mais comumns no conjunto de dados DS_OBJETO: ***** /n {freq_splits.most_common(10)}", "/n")
# Out:
# ***** As 10 strings mais comumns no conjunto de dados DS_OBJETO: ***** /n [('de', 30755), ('DE', 22676), ('para', 9982), ('e', 9914), ('PARA', 8780), ('Aquisição', 7625), ('AQUISIÇÃO', 6771), ('E', 6253), ('da', 4552), ('do', 4187)] /n

# %%
#Definindo strings "curtas" (short) com até 5 caracteres
short = set(i for i in splits if len(i)<5)
short = [(i, freq_splits[i]) for i in short]
short.sort(key = lambda x:x[1], reverse = True)
#short

#Observa-se especialmente múltiplos unitários como km, e conectivos (tokens)

# %%
#Definindo strings "longas" (long) com mais de 18 letras
#Considerar, palavras longas com mais de 20 letras,
#de acordo com norma culta (https://www.normaculta.com.br/palavras-grandes/)
#Critério de análise selecionado para 18 letras.

long = set(i for i in splits if len(i)>18)
long = [(i, freq_splits[i]) for i in long]
long.sort(key = lambda x:x[1], reverse = True)
#long

#Observa-se a identificacao de Numeros de identificacao, como por exemplo
#de chassi de veiculos

# %%
#Criando uma funcao (summarise) para identificar o percentual da ocorrencia de certas strings:
#Como por exemplo "CHASSI", "MEDICAMENTOS"

def summarise(pattern, strings, freq):
    """Funcao summarise encontra o padrao inserido"""
    #Encontrando os "matches"
    compiled_pattern = re.compile(pattern)
    matches = [i for i in strings if compiled_pattern.search(i)]
    
    #Volume e proporcao dos "matches"
    print("{} strings, que sao {: .2%} do total".format(len(matches), len(matches)/len(strings)))
    
    #Criacao de listas de tuplas com os "matches" e as frequencias determinadas
    output = [(i, freq[i]) for i in set(matches)]
    output.sort(key = lambda x:x[1], reverse = True)
    
    return output

# %%
#Verificando algumas frequencias --> EQUIPAMENTOS
#Função summarise também não executada por motivos de leitura e extensão dos dados
#summarise(r"EQUIPAMENTOS", splits, freq_splits)

# %%
#Verificando algumas frequencias --> FAMÍLIA
#Função summarise também não executada por motivos de leitura e extensão dos dados
#summarise(r"FAMÍLIA", splits, freq_splits)

# %%
#Verificando frequencias de números
#Função summarise também não executada por motivos de leitura e extensão dos dados
#summarise(r"\d", splits, freq_splits)

#Observa-se que estao presentes em ocasioes diversas,
#especialmente em identificacao

# %%
#Verificando a combinacao de palavras com pontuacoes diversas
#Justifica-se essa analise uma vez que nao há padrao na escrita

#Função summarise também não executada por motivos de leitura e extensão dos dados
#summarise(r"\w+[_!&/~'-)(<\|}{\[\]]\w+", splits, freq_splits)

# %% [markdown]
# ---
# ##   Tokenizacao dos caracteres;
#
#   Necessária aplicacao de Tokenizacao para eliminar pontuacoes e afins;
#
#   Essencialmente para identificar quantos tokens existem e quantos tokens unicos existem;
#
#   Fonte: https://nlp.stanford.edu/IR-book/html/htmledition/tokenization-1.html;
#
# ---

# %%
#Aplicando o processo de Tokenizacao (tokenizer)
tokeniser = RegexpTokenizer("[A-Za-z]+")
tokens = tokeniser.tokenize(train_string)
print(tokens[:20], "\n")
# Out:
# ['Aquisi', 'o', 'de', 'alimentos', 'AQUISI', 'O', 'DE', 'COMBUSTIVEIS', 'PARA', 'MANUTEN', 'O', 'DA', 'FROTA', 'MUNICIPAL', 'AQUISI', 'O', 'DE', 'PNEU', 'C', 'MARA']

# %%
#Com isso, podemos responder as questoes relevantes
print(f"O numero de tokens: {len(tokens)}")
print(f"O numero de tokens unicos: {len(set(tokens))}")
# Out:
# O numero de tokens: 460115
# O numero de tokens unicos: 20754

# %%
#Contudo, o numero de tokens é relativamente alto, um processo de normalizacao
#deve ser aplicado para padronizar letras maiúsculas e minúsculas (lower and upper cases)
#Para isso, utiliza-se o processo de lemmatization (agrupamento de formas flexionadas)
lemmatiser = WordNetLemmatizer()
tokens_norm = [lemmatiser.lemmatize(t.lower(), "v") for t in tokens]
print(f"O numero de tokens unicos é de: {len(set(tokens_norm))}")

#O numero de tokens reduziu de 4548 para 9738, aproximadamente 35%
# Out:
# O numero de tokens unicos é de: 13656

# %%
#Com isso, a analise decorre agora da analise dos tokens
#Analisando o "length" dos tokens e sua distribuicao

#Criacao de lista para o "length" de tokens
token_length = [len(t) for t in tokens]

#Numero médio de caracteres por token
print(f"Média de caracteres por token: {round(np.mean(token_length), 4)}")

#Plotando a distribuicao
# %matplotlib notebook
plt.figure(figsize = (8, 8))
sns.countplot(y = token_length)
plt.title("Extensão dos caracteres dos Tokens", size = 18)
plt.savefig('Token-Length.png', dpi = 300)

#Essa análise dos Tokens, é muito similar em termos de distribuição das anteriores, 
#identificando padrão ao longo dos anos.
# Out:
# Média de caracteres por token: 4.4885
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ---
# ##  Stopwords;
#
#  Identificacao de palavras que nao contribuem para o texto;
#
#  Por vezes sao conectivos e afins da linguagem;
#
#  Para as licitações, decidiu-se não acrescentar stopwords oriundas dos projetos e explorar os n-grams formados, podendo incluir stopwrods em seus contextos, especialmente os "five-grams".
#
# ---

# %%
#Criacao e verificacao das stopwords em Portugues
stop_words = stopwords.words("portuguese")
print(f"Há {len(stop_words)} stopwords.\n")
print(stop_words)
# Out:
# Há 204 stopwords.
#
# ['de', 'a', 'o', 'que', 'e', 'é', 'do', 'da', 'em', 'um', 'para', 'com', 'não', 'uma', 'os', 'no', 'se', 'na', 'por', 'mais', 'as', 'dos', 'como', 'mas', 'ao', 'ele', 'das', 'à', 'seu', 'sua', 'ou', 'quando', 'muito', 'nos', 'já', 'eu', 'também', 'só', 'pelo', 'pela', 'até', 'isso', 'ela', 'entre', 'depois', 'sem', 'mesmo', 'aos', 'seus', 'quem', 'nas', 'me', 'esse', 'eles', 'você', 'essa', 'num', 'nem', 'suas', 'meu', 'às', 'minha', 'numa', 'pelos', 'elas', 'qual', 'nós', 'lhe', 'deles', 'essas', 'esses', 'pelas', 'este', 'dele', 'tu', 'te', 'vocês', 'vos', 'lhes', 'meus', 'minhas', 'teu', 'tua', 'teus', 'tuas', 'nosso', 'nossa', 'nossos', 'nossas', 'dela', 'delas', 'esta', 'estes', 'estas', 'aquele', 'aquela', 'aqueles', 'aquelas', 'isto', 'aquilo', 'estou', 'está', 'estamos', 'estão', 'estive', 'esteve', 'estivemos', 'estiveram', 'estava', 'estávamos', 'estavam', 'estivera', 'estivéramos', 'esteja', 'estejamos', 'estejam', 'estivesse', 'estivéssemos', 'estivessem', 'estiver', 'estivermos', 'estiverem', 'hei', 'há', 'havemos', 'hão', 'houve', 'houvemos', 'houveram', 'houvera', 'houvéramos', 'haja', 'hajamos', 'hajam', 'houvesse', 'houvéssemos', 'houvessem', 'houver', 'houvermos', 'houverem', 'houverei', 'houverá', 'houveremos', 'houverão', 'houveria', 'houveríamos', 'houveriam', 'sou', 'somos', 'são', 'era', 'éramos', 'eram', 'fui', 'foi', 'fomos', 'foram', 'fora', 'fôramos', 'seja', 'sejamos', 'sejam', 'fosse', 'fôssemos', 'fossem', 'for', 'formos', 'forem', 'serei', 'será', 'seremos', 'serão', 'seria', 'seríamos', 'seriam', 'tenho', 'tem', 'temos', 'tém', 'tinha', 'tínhamos', 'tinham', 'tive', 'teve', 'tivemos', 'tiveram', 'tivera', 'tivéramos', 'tenha', 'tenhamos', 'tenham', 'tivesse', 'tivéssemos', 'tivessem', 'tiver', 'tivermos', 'tiverem', 'terei', 'terá', 'teremos', 'terão', 'teria', 'teríamos', 'teriam']

# %%
#Stopwords mais frequentes utilizadas
n_stopwords = len([t for t in tokens_norm if t in stop_words])
print(f"{n_stopwords} tokens são stopwords")
print(f"Isso corresponde a {round(100*n_stopwords/len(tokens_norm), 2)}%")
# Out:
# 181463 tokens são stopwords
# Isso corresponde a 39.44%

# %% [markdown]
# ---
# ##   n-gramas ou "n-grams";
#
#   Uso de n-grams para identificacao do conjunto de palavras mais relevantes;
#
#   Objetivando encontra a área de interesse mais frequente requisitada;
#
# ---

# %%
#Removendo as stopwords, para análise refinada dos n-grams
tokens_clean = [t for t in tokens_norm if t not in stop_words]
print(f"O número e tokens para análise dos n-grams é de: {len(tokens_clean)}")
print(f"Isso corresponde a redução de {round(100*len(tokens_clean)/len(tokens), 2)}% dos tokens originais")
# Out:
# O número e tokens para análise dos n-grams é de: 278652
# Isso corresponde a redução de 60.56% dos tokens originais

# %%
#Transforming X_train in DataFrame
X_train = pd.DataFrame(X_train)

# %%
#Com a remocao dos tokens, pode-se criar os n-grams: unigrams, bigrams, trigrams e fourgrams
#Com base na definicao das funcoes

def preprocess_text(text):
    """Pré-processamento do texto com tokens normalizados"""
    #Processo de "Tokenise"as palavras em modo alfabérico
    tokenizer = RegexpTokenizer(r'[A-Za-z]{2,}')
    tokens = tokenizer.tokenize(text)
    
    #Transformação em "lowercase" e processo de "lemmatise"
    lemmatiser = WordNetLemmatizer()
    lemmas = [lemmatiser.lemmatize(token.lower(), pos = 'v') for token in tokens]
    
    #Removendo stopwords
    keywords = [lemma for lemma in lemmas if lemma not in stop_words]
    return keywords

def get_frequent_ngram(corpus, ngram, n = 20):
    """Encontrando os n-grams mais comuns com os Tokens normalizados"""
    #Pré-processamento de cada documento
    documents = [preprocess_text(document) for document in corpus]
    
    #Encontrando n-grams por documento
    n_grams = [list(ngrams(document, ngram)) for document in documents]
    
    #Encontrando a frequência dos n-grams
    n_grams_flattened = [item for sublist in n_grams for item in sublist]
    freq_dist = FreqDist(n_grams_flattened)
    top_freq = freq_dist.most_common(n)
    return pd.DataFrame(top_freq, columns = ['ngram', 'count'])

"""
Optou-se por plotar individualmente, para melhor visualizacao
#Obtendo "uni", "bi", "tri" e "four-grams"
for i in range(1, 5):
    # %matplotlib notebook
    mapping = {1:"uni", 2:"bi", 3:"tri", 4:"four"}
    plt.figure(figsize=(25,15))
    sns.barplot(x = "count", y = "ngram",
data = get_frequent_ngram(X_train['DS_OBJETO'], i))
    plt.title(f"Mais comum {mapping[i]}grams")
    plt.savefig(f"Mais comum {mapping[i]}grams.png", dpi = 600"
"""
# Out:
# '\nOptou-se por plotar individualmente, para melhor visualizacao\n#Obtendo "uni", "bi", "tri" e "four-grams"\nfor i in range(1, 5):\n    %matplotlib notebook\n    mapping = {1:"uni", 2:"bi", 3:"tri", 4:"four"}\n    plt.figure(figsize=(25,15))\n    sns.barplot(x = "count", y = "ngram",\ndata = get_frequent_ngram(X_train[\'DS_OBJETO\'], i))\n    plt.title(f"Mais comum {mapping[i]}grams")\n    plt.savefig(f"Mais comum {mapping[i]}grams.png", dpi = 600"\n'

# %%
#Plotando uni-gram 
# %matplotlib notebook
mapping = {1:"uni"}
plt.figure(figsize=(10,10))
sns.barplot(x = "count", y = "ngram",
data = get_frequent_ngram(X_train['DS_OBJETO'], 1))
plt.title(f"Mais comum {mapping[1]}grams")
plt.savefig(f"Mais comum {mapping[1]}grams.png", dpi = 600)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
#Plotando bi-grams 
# %matplotlib notebook
mapping = {2:"bi"}
plt.figure(figsize=(15,10))
sns.barplot(x = "count", y = "ngram",
data = get_frequent_ngram(X_train['DS_OBJETO'], 2))
plt.title(f"Mais comum {mapping[2]}grams")
plt.savefig(f"Mais comum {mapping[2]}grams.png", dpi = 600)
# Out:
# <img src="data:image/png;base64,..." width="1500">

# %%
#Plotando tri-grams 
# %matplotlib notebook
mapping = {3:"tri"}
plt.figure(figsize=(25,10))
sns.barplot(x = "count", y = "ngram",
data = get_frequent_ngram(X_train['DS_OBJETO'], 3))
plt.title(f"Mais comum {mapping[3]}grams")
plt.savefig(f"Mais comum {mapping[3]}grams.png", dpi = 600)
# Out:
# <img src="data:image/png;base64,..." width="2500">

# %%
#Plotando four-grams
# %matplotlib notebook
mapping = {4:"four"}
plt.figure(figsize=(33,10))
sns.barplot(x = "count", y = "ngram",
data = get_frequent_ngram(X_train['DS_OBJETO'], 4))
plt.title(f"Mais comum {mapping[4]}grams")
plt.savefig(f"Mais comum {mapping[4]}grams.png", dpi = 600)
# Out:
# <img src="data:image/png;base64,..." width="3300">

# %%
#Plotando five-grams
# %matplotlib notebook
mapping = {5:"five"}
plt.figure(figsize=(40,10))
sns.barplot(x = "count", y = "ngram",
data = get_frequent_ngram(X_train['DS_OBJETO'], 5))
plt.title(f"Mais comum {mapping[5]}grams")
plt.savefig(f"Mais comum {mapping[5]}grams.png", dpi = 600)
# Out:
# <img src="data:image/png;base64,..." width="4000">

# %%
#Replotando o five-grams, sem formato de plot
data = get_frequent_ngram(X_train['DS_OBJETO'], 5)
data
# Out:
#                                                 ngram  count
# 0       (neros, aliment, cios, agricultura, familiar)    449
# 1         (aquisi, neros, aliment, cios, agricultura)    405
# 2    (aliment, cios, agricultura, familiar, alimenta)    216
# 3    (cios, agricultura, familiar, alimenta, escolar)    210
# 4   (agricultura, familiar, empreendedor, familiar...    179
# 5       (programa, nacional, alimenta, escolar, pnae)    177
# 6            (neros, aliment, cios, merenda, escolar)    164
# 7             (aquisi, neros, aliment, cios, merenda)    136
# 8   (aliment, cios, agricultura, familiar, empreen...    131
# 9                (registro, pre, futuras, aquisi, es)    126
# 10  (atendimento, programa, nacional, alimenta, es...    124
# 11  (cios, agricultura, familiar, empreendedor, fa...    117
# 12      (processo, licitat, rio, exclusivo, empresas)    116
# 13                (neros, aliment, cios, perec, veis)    107
# 14          (exclusivo, empresas, benefici, rias, lc)    102
# 15      (licitat, rio, exclusivo, empresas, benefici)     99
# 16         (rio, exclusivo, empresas, benefici, rias)     99
# 17      (secretaria, municipal, assist, ncia, social)     99
# 18                 (preg, eletr, nico, registro, pre)     94
# 19      (constitui, objeto, presente, licita, aquisi)     86

# %% [markdown]
# ---
# ##  Análise estatística dos produtos do NLP;
#
#  Objetivo de avalizacao dos tokens, caracteres, stopwords;
#
#  Esse recurso poderia ser melhor utilizado com agrupamento de categorias, como a questao a ser agrupada seria o CD_ORGAO, fica-se impossibilitado de plotar via grupos;
#
#  Estudo futuro poderia objetivar essa análise em grupos específicos.
#
# ---

# %%
#Criando métricas de análise para cada sentence e DS_OBJETO
#Responder: Qual o número de Tokens por documento?
#Qual a média de caracteres por documento?
#Qual a média de stopwrods por documento?
X_train["n_sentences"] = X_train['DS_OBJETO'].apply(sent_tokenize).apply(len)
X_train["tokens"] = X_train['DS_OBJETO'].apply(tokeniser.tokenize)
X_train["n_tokens"] = X_train["tokens"].apply(len)
X_train["n_characters"] = X_train['DS_OBJETO'].apply(len)
X_train["n_stopwords"] = X_train["tokens"].apply(lambda tokens: len([t for t in tokens if t in stop_words]))
X_train["p_stopwords"] = X_train["n_stopwords"]/X_train["n_tokens"]

# %%
#Replotando o conjunto de dados com as métricas
X_train
# Out:
#                                                DS_OBJETO  n_sentences  \
# 2                                Aquisição de alimentos.            1
# 4      AQUISIÇÃO DE COMBUSTIVEIS PARA MANUTENÇÃO DA F...            1
# 20     "AQUISIÇÃO DE PNEU/CÂMARA/ COLARINHO NOVOS PAR...            1
# 24                      Aquisição de óleos lubrificantes            1
# 25     CONTRATAÇÃO DE EMPRESA PARA FORNECIMENTO DE CO...            1
# ...                                                  ...          ...
# 62840                            Aquisição de camisetas.            1
# 62847  Aquisição de GÊNEROS ALIMENTÍCIOS DA AGRICULTU...            1
# 62848  Aquisição de GÊNEROS ALIMENTÍCIOS DA AGRICULTU...            1
# 62860  Aquisição de gêneros alimentícios da Agricultu...            1
# 62877                           WORKSTATION HP INC Z 440            1
#
#                                                   tokens  n_tokens  \
# 2                             [Aquisi, o, de, alimentos]         4
# 4      [AQUISI, O, DE, COMBUSTIVEIS, PARA, MANUTEN, O...        10
# 20     [AQUISI, O, DE, PNEU, C, MARA, COLARINHO, NOVO...        17
# 24                  [Aquisi, o, de, leos, lubrificantes]         5
# 25     [CONTRATA, O, DE, EMPRESA, PARA, FORNECIMENTO,...        26
# ...                                                  ...       ...
# 62840                         [Aquisi, o, de, camisetas]         4
# 62847  [Aquisi, o, de, G, NEROS, ALIMENT, CIOS, DA, A...        36
# 62848  [Aquisi, o, de, G, NEROS, ALIMENT, CIOS, DA, A...        36
# 62860  [Aquisi, o, de, g, neros, aliment, cios, da, A...        20
# 62877                          [WORKSTATION, HP, INC, Z]         4
#
#        n_characters  n_stopwords  p_stopwords
# 2                23            2     0.500000
# 4                60            0     0.000000
# 20               93            0     0.000000
# 24               32            2     0.400000
# 25              162            0     0.000000
# ...             ...          ...          ...
# 62840            23            2     0.500000
# 62847           208           10     0.277778
# 62848           208           10     0.277778
# 62860           130            6     0.300000
# 62877            24            0     0.000000
#
# [22625 rows x 7 columns]

# %%
#Analisando o "head()"
columns = ['DS_OBJETO', 'n_sentences', 'n_tokens', 'n_characters', 'n_stopwords', 'p_stopwords']
X_train[columns].head()
# Out:
#                                             DS_OBJETO  n_sentences  n_tokens  \
# 2                             Aquisição de alimentos.            1         4
# 4   AQUISIÇÃO DE COMBUSTIVEIS PARA MANUTENÇÃO DA F...            1        10
# 20  "AQUISIÇÃO DE PNEU/CÂMARA/ COLARINHO NOVOS PAR...            1        17
# 24                   Aquisição de óleos lubrificantes            1         5
# 25  CONTRATAÇÃO DE EMPRESA PARA FORNECIMENTO DE CO...            1        26
#
#     n_characters  n_stopwords  p_stopwords
# 2             23            2          0.5
# 4             60            0          0.0
# 20            93            0          0.0
# 24            32            2          0.4
# 25           162            0          0.0

# %%
#Descrevendo estatisticamente o conjunto
X_train.describe()
# Out:
#         n_sentences      n_tokens  n_characters   n_stopwords   p_stopwords
# count  22625.000000  22625.000000   22625.00000  22625.000000  22509.000000
# mean       1.124950     20.336575     118.59642      4.674564      0.212356
# std        0.646629     21.119583     125.29451      7.390433      0.204185
# min        1.000000      0.000000       3.00000      0.000000      0.000000
# 25%        1.000000      9.000000      53.00000      0.000000      0.000000
# 50%        1.000000     15.000000      88.00000      2.000000      0.255319
# 75%        1.000000     25.000000     142.00000      7.000000      0.400000
# max       28.000000    368.000000    2000.00000    153.000000      0.666667

# %%
#Informacoes do conjunto de dados
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22625 entries, 2 to 62877
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   DS_OBJETO     22625 non-null  object
#  1   n_sentences   22625 non-null  int64
#  2   tokens        22625 non-null  object
#  3   n_tokens      22625 non-null  int64
#  4   n_characters  22625 non-null  int64
#  5   n_stopwords   22625 non-null  int64
#  6   p_stopwords   22509 non-null  float64
# dtypes: float64(1), int64(4), object(2)
# memory usage: 1.4+ MB

# %%
#Agregando o conjunto de dados
num_vars = X_train.select_dtypes(np.number).columns
X_train.groupby("DS_OBJETO")[num_vars].agg(["mean", "median"])
# Out:
#                                                    n_sentences         \
#                                                           mean median
# DS_OBJETO
# \t  Contratação de empresa(s) especializada(s) ...         1.0    1.0
# \tAQUISIÇÃO DE PEÇAS PARA MOTOR DA FROTA VW CODECA         1.0    1.0
# \tEDITAL DE CHAMADA PÚBLICA N° 01/2017- AQUISIÇ...         1.0    1.0
#       O presente Pregão Presencial tem por obje...         1.0    1.0
#   REGISTO DE PREÇOS PARA FUTURA AQUISIÇÃO DE BA...         1.0    1.0
# ...                                                        ...    ...
# “Licitação pública para aquisição de cortador d...         1.0    1.0
# “Licitação pública para aquisição de um veículo...         1.0    1.0
# “Licitação pública para aquisição de uma escava...         1.0    1.0
# “Licitação pública para aquisição de uma escava...         1.0    1.0
# “REGISTRO DE PREÇOS” de TUBOS DE CONCRETO, MEIO...         1.0    1.0
#
#                                                    n_tokens         \
#                                                        mean median
# DS_OBJETO
# \t  Contratação de empresa(s) especializada(s) ...     32.0   32.0
# \tAQUISIÇÃO DE PEÇAS PARA MOTOR DA FROTA VW CODECA     11.0   11.0
# \tEDITAL DE CHAMADA PÚBLICA N° 01/2017- AQUISIÇ...     20.0   20.0
#       O presente Pregão Presencial tem por obje...     37.0   37.0
#   REGISTO DE PREÇOS PARA FUTURA AQUISIÇÃO DE BA...     33.0   33.0
# ...                                                     ...    ...
# “Licitação pública para aquisição de cortador d...     39.0   39.0
# “Licitação pública para aquisição de um veículo...     42.0   42.0
# “Licitação pública para aquisição de uma escava...     34.0   34.0
# “Licitação pública para aquisição de uma escava...     34.0   34.0
# “REGISTRO DE PREÇOS” de TUBOS DE CONCRETO, MEIO...     32.0   32.0
#
#                                                    n_characters         \
#                                                            mean median
# DS_OBJETO
# \t  Contratação de empresa(s) especializada(s) ...        200.0  200.0
# \tAQUISIÇÃO DE PEÇAS PARA MOTOR DA FROTA VW CODECA         49.0   49.0
# \tEDITAL DE CHAMADA PÚBLICA N° 01/2017- AQUISIÇ...        122.0  122.0
#       O presente Pregão Presencial tem por obje...        213.0  213.0
#   REGISTO DE PREÇOS PARA FUTURA AQUISIÇÃO DE BA...        155.0  155.0
# ...                                                         ...    ...
# “Licitação pública para aquisição de cortador d...        220.0  220.0
# “Licitação pública para aquisição de um veículo...        226.0  226.0
# “Licitação pública para aquisição de uma escava...        188.0  188.0
# “Licitação pública para aquisição de uma escava...        192.0  192.0
# “REGISTRO DE PREÇOS” de TUBOS DE CONCRETO, MEIO...        194.0  194.0
#
#                                                    n_stopwords         \
#                                                           mean median
# DS_OBJETO
# \t  Contratação de empresa(s) especializada(s) ...        11.0   11.0
# \tAQUISIÇÃO DE PEÇAS PARA MOTOR DA FROTA VW CODECA         0.0    0.0
# \tEDITAL DE CHAMADA PÚBLICA N° 01/2017- AQUISIÇ...         0.0    0.0
#       O presente Pregão Presencial tem por obje...        13.0   13.0
#   REGISTO DE PREÇOS PARA FUTURA AQUISIÇÃO DE BA...         0.0    0.0
# ...                                                        ...    ...
# “Licitação pública para aquisição de cortador d...        14.0   14.0
# “Licitação pública para aquisição de um veículo...        12.0   12.0
# “Licitação pública para aquisição de uma escava...        12.0   12.0
# “Licitação pública para aquisição de uma escava...        12.0   12.0
# “REGISTRO DE PREÇOS” de TUBOS DE CONCRETO, MEIO...         6.0    6.0
#
#                                                    p_stopwords
#                                                           mean    median
# DS_OBJETO
# \t  Contratação de empresa(s) especializada(s) ...    0.343750  0.343750
# \tAQUISIÇÃO DE PEÇAS PARA MOTOR DA FROTA VW CODECA    0.000000  0.000000
# \tEDITAL DE CHAMADA PÚBLICA N° 01/2017- AQUISIÇ...    0.000000  0.000000
#       O presente Pregão Presencial tem por obje...    0.351351  0.351351
#   REGISTO DE PREÇOS PARA FUTURA AQUISIÇÃO DE BA...    0.000000  0.000000
# ...                                                        ...       ...
# “Licitação pública para aquisição de cortador d...    0.358974  0.358974
# “Licitação pública para aquisição de um veículo...    0.285714  0.285714
# “Licitação pública para aquisição de uma escava...    0.352941  0.352941
# “Licitação pública para aquisição de uma escava...    0.352941  0.352941
# “REGISTRO DE PREÇOS” de TUBOS DE CONCRETO, MEIO...    0.187500  0.187500
#
# [20318 rows x 10 columns]

# %% [markdown]
# ---
# ###  _*Discussão da análise dos dados NLP*_
#
# Para o presente ano, 2017, identificou-se também o padrão de ordens de licitações quanto ao "pnae-programa nacional de alimentação escolar". Além dos padrões encontrados em anos anteriores: alimentícios e agricultura familiar.

# %% [markdown]
# ---
# ##  _*DISCUSSÕES E CONCLUSÕES- Ano 2017 - licitacoes.csv*_
#
#
#  De acordo com a análise exploratória submetida em duas etapas, para análise numérica e categórica, algumas conclusoes podem ser obtidas:
#
#  a) Em relação à análise via montante de Valor Homologado (VL_HOMOLOGADO), obteu-se resultados relevantes para elencar os 5 principais órgãos: PM de Herval, PM de Cangaçu, Cons. Associação dos Municípios, PM re Rosário do Sul e PM de Eldorado do sul. Justifica-se para o ano de 2017 em coerencia da análise e procedimento de "group by" e seleção de pares;
#
#  b) Em relação à análise NLP e os atributos oriundas da doluna DS_OBJETO, foi possível desenvolver uma análise exploratória com os principais domínios de processo NLP. Identificacao de tokens, de stopwords e n=grams. Com isso, observa-se, especialmente com base no "Mais comum four-grams" que a aquisicao de alimentos e produtos alimentícios é a fonte de maior pedidos em termos de licitaçoes para o ano observado. O intuito da presente análise foi identificar "ramos" e não especificamente produtos;
#
#  c) Os primeiros n-grams (uni e bi) sugerem a existencia de palavras usais descrevendo "aquisicao", "registro", "municipio". Já uma análise com os n-grams (tri e four) permitem identificar dados padroes contundentes em relacao a áreas de pedidos de licitacao, com destaque para: "alimenticia", "agricultura familiar" e "pnae", ;
#
#  d) Com tais análises é possível identificar o padrão, através da análise exploratória dos pedidos solicitados pelos diversos órgaos do estado do Rio Grande do Sul. Em termos quantitativos e qualitativos.
#
# ---
